# %%
import pandas as pd

# %%
topics = pd.read_excel('data/topics.xlsx')
projects = pd.read_excel('data/project.xlsx')
euroscivoc = pd.read_excel('data/euroSciVoc.xlsx')
orgs = pd.read_excel('data/organization.xlsx')
# Out:
# E:\Code\hoponfacilities\venv\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# E:\Code\hoponfacilities\venv\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# E:\Code\hoponfacilities\venv\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# E:\Code\hoponfacilities\venv\lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
projects['startDate']= pd.to_datetime(projects['startDate'],errors = 'coerce')
projects['endDate']= pd.to_datetime(projects['endDate'],errors = 'coerce')
projects.info()

from datetime import datetime
filterdate = datetime(2024,1,1)
projects23 = projects[projects['startDate']>=filterdate]
projects23 = projects23[projects23['endDate']>=datetime(2026,1,1)]
projects23
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14970 entries, 0 to 14969
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  14970 non-null  int64
#  1   acronym             14970 non-null  object
#  2   status              14970 non-null  object
#  3   title               14970 non-null  object
#  4   startDate           14970 non-null  datetime64[ns]
#  5   endDate             14970 non-null  datetime64[ns]
#  6   totalCost           14970 non-null  object
#  7   ecMaxContribution   14970 non-null  object
#  8   legalBasis          14970 non-null  object
#  9   topics              14970 non-null  object
#  10  ecSignatureDate     14968 non-null  object
#  11  frameworkProgramme  14970 non-null  object
#  12  masterCall          14970 non-null  object
#  13  subCall             14970 non-null  object
#  14  fundingScheme       14969 non-null  object
#  15  nature              0 non-null      float64
#  16  objective           14970 non-null  object
#  17  contentUpdateDate   14970 non-null  object
#  18  rcn                 14970 non-null  int64
#  19  grantDoi            14911 non-null  object
# dtypes: datetime64[ns](2), float64(1), int64(2), object(15)
# memory usage: 2.3+ MB
#               id           acronym  status  \
# 1      101193001  Impact Monitor 2  SIGNED
# 2      101165479          RE-TWIST  SIGNED
# 3      101191725           InFlaMe  SIGNED
# 4      101191867           EPISODE  SIGNED
# 5      101147312            SAGELI  SIGNED
# ...          ...               ...     ...
# 14957  101161603       E.T.COMPACT  SIGNED
# 14959  101161137          FROSTBIT  SIGNED
# 14961  101129638            ICONIC  SIGNED
# 14968  101189207           AWE-KM2  SIGNED
# 14969  101131516         FlexRICAN  SIGNED
#
#                                                    title  startDate  \
# 1                                       Impact Monitor 2 2025-02-01
# 2      REinforcement TWInning SysTems: from collabora... 2025-02-01
# 3      Counter-acting the pandemic potential of flavi... 2025-01-01
# 4      European Produced sustaInable SODium-ion battE... 2024-12-01
# 5      ADVANCED SAFER MATERIALS AND HIGH PERFORMING C... 2025-01-01
# ...                                                  ...        ...
# 14957  COMPACT AND PROPELLANT-LESS ELECTRODYNAMIC TET... 2024-10-01
# 14959  First Regenerative sOlid-STate Barocaloric ref... 2024-10-01
# 14961  In-situ & operando organiC electrochemical tra... 2024-05-01
# 14968  Airborne Wind Energy: Innovative KM2 AWE Syste... 2024-10-01
# 14969    Flexibility in RIs for global CArbon Neutrality 2024-03-01
#
#          endDate   totalCost ecMaxContribution   legalBasis  \
# 1     2028-01-31     3000000           3000000  HORIZON.2.5
# 2     2030-01-31     1500000           1500000  HORIZON.1.1
# 3     2028-12-31   7995922,4         7995922,4  HORIZON.2.1
# 4     2028-05-31           0        6597981,39  HORIZON.2.5
# 5     2027-12-31  4975670,75        4975669,75  HORIZON.2.5
# ...          ...         ...               ...          ...
# 14957 2027-09-30     3972890           3972890  HORIZON.3.1
# 14959 2028-09-30   3427222,5         3427222,5  HORIZON.3.1
# 14961 2028-04-30     2664940           2664940  HORIZON.3.1
# 14968 2026-09-30           0           2499000  HORIZON.3.1
# 14969 2027-02-28           0         4991962,5  HORIZON.1.3
#
#                                             topics ecSignatureDate  \
# 1                        HORIZON-CL5-2024-D5-01-09      2024-12-02
# 2                                     ERC-2024-STG      2024-12-02
# 3                  HORIZON-HLTH-2024-DISEASE-08-20      2024-12-02
# 4                        HORIZON-CL5-2024-D2-01-02      2024-11-29
# 5                        HORIZON-CL5-2023-D2-02-02      2024-11-18
# ...                                            ...             ...
# 14957  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01-05      2024-06-16
# 14959  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01-01      2024-06-10
# 14961        HORIZON-EIC-2023-PATHFINDEROPEN-01-01      2023-11-08
# 14968    HORIZON-EIC-2024-ACCELERATORCHALLENGES-06      2024-11-28
# 14969                HORIZON-INFRA-2023-TECH-01-01      2023-10-23
#
#       frameworkProgramme                                masterCall  \
# 1                HORIZON                    HORIZON-CL5-2024-D5-01
# 2                HORIZON                              ERC-2024-STG
# 3                HORIZON              HORIZON-HLTH-2024-DISEASE-08
# 4                HORIZON                    HORIZON-CL5-2024-D2-01
# 5                HORIZON                    HORIZON-CL5-2023-D2-02
# ...                  ...                                       ...
# 14957            HORIZON  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01
# 14959            HORIZON  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01
# 14961            HORIZON        HORIZON-EIC-2023-PATHFINDEROPEN-01
# 14968            HORIZON           HORIZON-EIC-2024-ACCELERATOR-02
# 14969            HORIZON                HORIZON-INFRA-2023-TECH-01
#
#                                         subCall    fundingScheme  nature  \
# 1                        HORIZON-CL5-2024-D5-01      HORIZON-RIA     NaN
# 2                                  ERC-2024-STG      HORIZON-ERC     NaN
# 3                  HORIZON-HLTH-2024-DISEASE-08      HORIZON-RIA     NaN
# 4                        HORIZON-CL5-2024-D2-01       HORIZON-IA     NaN
# 5                        HORIZON-CL5-2023-D2-02      HORIZON-RIA     NaN
# ...                                         ...              ...     ...
# 14957  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01      HORIZON-EIC     NaN
# 14959  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01      HORIZON-EIC     NaN
# 14961        HORIZON-EIC-2023-PATHFINDEROPEN-01      HORIZON-EIC     NaN
# 14968           HORIZON-EIC-2024-ACCELERATOR-02  HORIZON-EIC-ACC     NaN
# 14969                HORIZON-INFRA-2023-TECH-01      HORIZON-RIA     NaN
#
#                                                objective    contentUpdateDate  \
# 1      Impact Monitor 2 is a project to deliver a coh...  2024-12-12 11:00:46
# 2      "The concept of digital twins promises to revo...  2024-12-12 11:42:39
# 3      To strengthen EU's ability to fight DENV and W...  2024-12-12 11:00:45
# 4      The main mission for EPISODE is to develop a n...  2024-12-12 11:00:44
# 5      SAGELi aims to develop safer materials and cel...  2024-12-12 11:00:23
# ...                                                  ...                  ...
# 14957  E.T.COMPACT is aimed at reaching technology re...  2024-06-24 10:42:44
# 14959  Greenhouse gas emissions for refrigeration sys...  2024-06-17 12:50:54
# 14961  Ultra-flexible, conformable and implantable ar...  2024-09-06 17:45:33
# 14968  The energy sector is the most polluting indust...  2024-12-09 10:00:58
# 14969  The FlexRICAN project brings together three la...  2024-09-06 18:33:46
#
#           rcn           grantDoi
# 1      268041  10.3030/101193001
# 2      268016  10.3030/101165479
# 3      268032  10.3030/101191725
# 4      268027  10.3030/101191867
# 5      267735  10.3030/101147312
# ...       ...                ...
# 14957  264516  10.3030/101161603
# 14959  264057  10.3030/101161137
# 14961  258154  10.3030/101129638
# 14968  267934  10.3030/101189207
# 14969  257840  10.3030/101131516
#
# [6151 rows x 20 columns]

# %%
projectIDs = projects23['id'].tolist()

# %%
orgs
# Out:
#        projectID  projectAcronym  organisationID       vatNumber  \
# 0      101113245  EIT Digital BP       897714437     GB267089763
# 1      101113245  EIT Digital BP       888552011    BE0700827077
# 2      101113245  EIT Digital BP       887518282  SE802506144401
# 3      101113245  EIT Digital BP       893135746     ESG87900874
# 4      101113245  EIT Digital BP       887937031      FI28441107
# ...          ...             ...             ...             ...
# 97391  101131516       FlexRICAN       983194329  SE556016864201
# 97392  101131516       FlexRICAN       910554618    BE0628655020
# 97393  101131516       FlexRICAN       919998053  SE768200001801
# 97394  101131516       FlexRICAN       999997930   FR40180089013
# 97395  101131516       FlexRICAN       999470541     DE140213784
#
#                                                     name           shortName  \
# 0                                         EIT DIGITAL UK  EIT DIGITAL UK LTD
# 1                                EIT DIGITAL ACCELERATOR                 NaN
# 2                                     EIT DIGITAL SWEDEN                 NaN
# 3                                      EIT DIGITAL SPAIN                 NaN
# 4                                 EIT DIGITAL FINLAND RY                 NaN
# ...                                                  ...                 ...
# 97391                         ALFA LAVAL TECHNOLOGIES AB                 NaN
# 97392                 EUROPEAN MAGNETIC FIELD LABORATORY        EMFL - AISBL
# 97393                    EUROPEAN SPALLATION SOURCE ERIC                 NaN
# 97394  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS                CNRS
# 97395            HELMHOLTZ-ZENTRUM DRESDEN-ROSSENDORF EV                HZDR
#
#          SME activityType                                             street  \
# 0      False          OTH                                  46 WICKLOW STREET
# 1      False          OTH                                      RUE GUIMARD 7
# 2      False          OTH                                       TORSGATAN 11
# 3      False          OTH  EDIFICIO IMDEA SOFTWARE CAMPUS DE MONTEGANCEDO...
# 4      False          OTH                                        MAARINTIE 6
# ...      ...          ...                                                ...
# 97391  False          PRC                                    RUDEBOKSVAGEN 1
# 97392  False          OTH                                    RUE DU TRONE 98
# 97393  False          PUB                                 ODARSLOVSVAGEN 113
# 97394  False          REC                                  RUE MICHEL ANGE 3
# 97395  False          REC                           BAUTZNER LANDSTRASSE 400
#
#        postCode  ...                                        contactForm  \
# 0      WC1X 9JH  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 1          1040  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 2        111 23  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 3         28223  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 4         02150  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# ...         ...  ...                                                ...
# 97391    221 00  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 97392      1050  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 97393    224 84  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 97394     75794  ...  https://ec.europa.eu/info/funding-tenders/oppo...
# 97395     01328  ...  https://ec.europa.eu/info/funding-tenders/oppo...
#
#          contentUpdateDate      rcn order         role ecContribution  \
# 0      2023-06-28 16:59:04  1981607   1.0   thirdParty            0.0
# 1      2023-06-28 16:59:04  1973441   1.0   thirdParty            0.0
# 2      2023-06-28 16:59:04  1981597   1.0   thirdParty            0.0
# 3      2023-06-28 16:59:04  1981603   1.0   thirdParty            0.0
# 4      2023-06-28 16:59:04  1981600   1.0   thirdParty            0.0
# ...                    ...      ...   ...          ...            ...
# 97391  2024-09-06 18:33:46  3099835   7.0  participant       106250.0
# 97392  2024-09-06 18:33:46  1965488   5.0  participant        37500.0
# 97393  2024-09-06 18:33:46  2720567   1.0  coordinator      1935725.0
# 97394  2024-09-06 18:33:46  1905572   3.0  participant      1118375.0
# 97395  2024-09-06 18:33:46  1909706   4.0  participant        78500.0
#
#       netEcContribution  totalCost  endOfParticipation active
# 0                   0.0          0               False    NaN
# 1             1740000.0          0               False    NaN
# 2               55875.0          0               False    NaN
# 3             1427500.0          0               False    NaN
# 4             1426250.0          0               False    NaN
# ...                 ...        ...                 ...    ...
# 97391          106250.0          0               False    NaN
# 97392           37500.0          0               False    NaN
# 97393         1935725.0          0               False    NaN
# 97394         1086382.0          0               False    NaN
# 97395           78500.0          0               False    NaN
#
# [97396 rows x 25 columns]

# %%
orgsinproj = orgs[orgs['projectID'].isin(projectIDs)]
orgsinproj
# Out:
#        projectID    projectAcronym  organisationID       vatNumber  \
# 8      101193001  Impact Monitor 2       998616262    BE0476966024
# 9      101193001  Impact Monitor 2       999987066  NL002760551B01
# 10     101193001  Impact Monitor 2       999994438   FR36775722879
# 11     101193001  Impact Monitor 2       999981731     DE121965658
# 12     101193001  Impact Monitor 2       984454068    BE0826094461
# ...          ...               ...             ...             ...
# 97391  101131516         FlexRICAN       983194329  SE556016864201
# 97392  101131516         FlexRICAN       910554618    BE0628655020
# 97393  101131516         FlexRICAN       919998053  SE768200001801
# 97394  101131516         FlexRICAN       999997930   FR40180089013
# 97395  101131516         FlexRICAN       999470541     DE140213784
#
#                                                     name  \
# 8                            TRANSPORT & MOBILITY LEUVEN
# 9      STICHTING KONINKLIJK NEDERLANDS LUCHT - EN RUI...
# 10     OFFICE NATIONAL D'ETUDES ET DE RECHERCHES AERO...
# 11         DEUTSCHES ZENTRUM FUR LUFT - UND RAUMFAHRT EV
# 12              EASN TECHNOLOGY INNOVATION SERVICES BVBA
# ...                                                  ...
# 97391                         ALFA LAVAL TECHNOLOGIES AB
# 97392                 EUROPEAN MAGNETIC FIELD LABORATORY
# 97393                    EUROPEAN SPALLATION SOURCE ERIC
# 97394  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS
# 97395            HELMHOLTZ-ZENTRUM DRESDEN-ROSSENDORF EV
#
#                                           shortName    SME activityType  \
# 8                                               TML   True          PRC
# 9      Royal Netherlands Aerospace Centre Amsterdam  False          REC
# 10                                            ONERA  False          REC
# 11                                              DLR  False          REC
# 12                                         EASN TIS   True          PRC
# ...                                             ...    ...          ...
# 97391                                           NaN  False          PRC
# 97392                                  EMFL - AISBL  False          OTH
# 97393                                           NaN  False          PUB
# 97394                                          CNRS  False          REC
# 97395                                          HZDR  False          REC
#
#                          street postCode  ...  \
# 8            DIESTSESTEENWEG 71     3010  ...
# 9           ANTHONY FOKKERWEG 2  1059 CM  ...
# 10         CHEMIN DE LA HUNIERE    91120  ...
# 11                  LINDER HOHE    51147  ...
# 12           TERWEIDENSTRAAT 28     3440  ...
# ...                         ...      ...  ...
# 97391           RUDEBOKSVAGEN 1   221 00  ...
# 97392           RUE DU TRONE 98     1050  ...
# 97393        ODARSLOVSVAGEN 113   224 84  ...
# 97394         RUE MICHEL ANGE 3    75794  ...
# 97395  BAUTZNER LANDSTRASSE 400    01328  ...
#
#                                              contactForm    contentUpdateDate  \
# 8      https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:46
# 9      https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:46
# 10     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:46
# 11     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:46
# 12     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:46
# ...                                                  ...                  ...
# 97391  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 18:33:46
# 97392  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 18:33:46
# 97393  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 18:33:46
# 97394  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 18:33:46
# 97395  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 18:33:46
#
#            rcn order         role ecContribution netEcContribution  \
# 8      1911517  10.0  participant      121375.00         121375.00
# 9      1905669   5.0  participant      473911.50         473911.50
# 10     1905624   6.0  participant      474681.00         474681.00
# 11     1905579   1.0  coordinator     1158016.25        1158016.25
# 12     1911071   4.0  participant       75035.00          75035.00
# ...        ...   ...          ...            ...               ...
# 97391  3099835   7.0  participant      106250.00         106250.00
# 97392  1965488   5.0  participant       37500.00          37500.00
# 97393  2720567   1.0  coordinator     1935725.00        1935725.00
# 97394  1905572   3.0  participant     1118375.00        1086382.00
# 97395  1909706   4.0  participant       78500.00          78500.00
#
#         totalCost  endOfParticipation active
# 8          121375               False    NaN
# 9        473911,5               False    NaN
# 10         474681               False    NaN
# 11     1158016,25               False    NaN
# 12          75035               False    NaN
# ...           ...                 ...    ...
# 97391           0               False    NaN
# 97392           0               False    NaN
# 97393           0               False    NaN
# 97394           0               False    NaN
# 97395           0               False    NaN
#
# [39079 rows x 25 columns]

# %%
print (orgsinproj['country'].unique())
# Out:
# ['BE' 'NL' 'FR' 'DE' 'ES' 'IT' 'UK' 'EL' 'AT' 'CZ' 'EE' 'LT' 'PT' 'AM'
#  'SK' 'MT' 'PL' 'TN' 'HU' 'DK' 'CH' 'IL' 'SE' 'IE' 'HR' 'BG' 'FI' 'RO'
#  'MZ' 'ET' 'NO' 'MA' 'LU' 'SN' 'ZA' 'CM' 'NG' 'KE' 'RW' 'ML' 'BF' 'TZ'
#  'CO' 'TR' 'CY' 'SI' 'RS' 'US' 'UA' 'LB' 'JP' 'NZ' 'AU' 'BD' 'GT' 'IN'
#  'GH' 'ZM' 'LV' 'CV' 'CA' 'AO' 'UG' 'CD' 'CI' 'CL' 'MV' 'SG' 'BA' 'MK'
#  'IS' 'PE' 'PH' 'GW' 'ST' 'KH' 'CN' 'GE' 'BR' 'TG' 'FO' 'KR' 'AD' nan 'AR'
#  'BJ' 'PG' 'DZ' 'EG' 'ZW' 'JO' 'AL' 'MW' 'GA' 'ME' 'MX' 'PY' 'CR' 'BO'
#  'NP' 'MO' 'MY' 'UZ' 'MD' 'TH' 'LK' 'KZ' 'LA' 'ID' 'VN' 'KG' 'XK' 'CU'
#  'TM' 'TJ' 'AZ' 'FJ' 'GU' 'MN' 'EC' 'VA' 'BI' 'HK' 'CG' 'GL' 'TW' 'MG'
#  'UY' 'SV' 'PK' 'CF' 'BW' 'GN' 'SA' 'IR' 'AW' 'AE' 'DO' 'SR' 'PF' 'DJ'
#  'TD' 'MC' 'LI' 'QA' 'PA']

# %%
projectsIDS_with_greeks = orgsinproj[orgsinproj['country']=='EL']
projectsIDS_with_greeksList = projectsIDS_with_greeks['projectID'].tolist()

# %%
projects23_no_greek = projects23[~projects23['id'].isin(projectsIDS_with_greeksList)]
projects23_no_greek
# Out:
#               id      acronym  status  \
# 2      101165479     RE-TWIST  SIGNED
# 3      101191725      InFlaMe  SIGNED
# 4      101191867      EPISODE  SIGNED
# 5      101147312       SAGELI  SIGNED
# 7      101188638     Bio2Skin  SIGNED
# ...          ...          ...     ...
# 14957  101161603  E.T.COMPACT  SIGNED
# 14959  101161137     FROSTBIT  SIGNED
# 14961  101129638       ICONIC  SIGNED
# 14968  101189207      AWE-KM2  SIGNED
# 14969  101131516    FlexRICAN  SIGNED
#
#                                                    title  startDate  \
# 2      REinforcement TWInning SysTems: from collabora... 2025-02-01
# 3      Counter-acting the pandemic potential of flavi... 2025-01-01
# 4      European Produced sustaInable SODium-ion battE... 2024-12-01
# 5      ADVANCED SAFER MATERIALS AND HIGH PERFORMING C... 2025-01-01
# 7      Bio2Skin, the first clinically skin-preserving... 2024-11-01
# ...                                                  ...        ...
# 14957  COMPACT AND PROPELLANT-LESS ELECTRODYNAMIC TET... 2024-10-01
# 14959  First Regenerative sOlid-STate Barocaloric ref... 2024-10-01
# 14961  In-situ & operando organiC electrochemical tra... 2024-05-01
# 14968  Airborne Wind Energy: Innovative KM2 AWE Syste... 2024-10-01
# 14969    Flexibility in RIs for global CArbon Neutrality 2024-03-01
#
#          endDate   totalCost ecMaxContribution   legalBasis  \
# 2     2030-01-31     1500000           1500000  HORIZON.1.1
# 3     2028-12-31   7995922,4         7995922,4  HORIZON.2.1
# 4     2028-05-31           0        6597981,39  HORIZON.2.5
# 5     2027-12-31  4975670,75        4975669,75  HORIZON.2.5
# 7     2026-10-31           0           2492571  HORIZON.3.1
# ...          ...         ...               ...          ...
# 14957 2027-09-30     3972890           3972890  HORIZON.3.1
# 14959 2028-09-30   3427222,5         3427222,5  HORIZON.3.1
# 14961 2028-04-30     2664940           2664940  HORIZON.3.1
# 14968 2026-09-30           0           2499000  HORIZON.3.1
# 14969 2027-02-28           0         4991962,5  HORIZON.1.3
#
#                                             topics ecSignatureDate  \
# 2                                     ERC-2024-STG      2024-12-02
# 3                  HORIZON-HLTH-2024-DISEASE-08-20      2024-12-02
# 4                        HORIZON-CL5-2024-D2-01-02      2024-11-29
# 5                        HORIZON-CL5-2023-D2-02-02      2024-11-18
# 7              HORIZON-EIC-2024-ACCELERATOROPEN-01      2024-11-20
# ...                                            ...             ...
# 14957  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01-05      2024-06-16
# 14959  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01-01      2024-06-10
# 14961        HORIZON-EIC-2023-PATHFINDEROPEN-01-01      2023-11-08
# 14968    HORIZON-EIC-2024-ACCELERATORCHALLENGES-06      2024-11-28
# 14969                HORIZON-INFRA-2023-TECH-01-01      2023-10-23
#
#       frameworkProgramme                                masterCall  \
# 2                HORIZON                              ERC-2024-STG
# 3                HORIZON              HORIZON-HLTH-2024-DISEASE-08
# 4                HORIZON                    HORIZON-CL5-2024-D2-01
# 5                HORIZON                    HORIZON-CL5-2023-D2-02
# 7                HORIZON           HORIZON-EIC-2024-ACCELERATOR-02
# ...                  ...                                       ...
# 14957            HORIZON  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01
# 14959            HORIZON  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01
# 14961            HORIZON        HORIZON-EIC-2023-PATHFINDEROPEN-01
# 14968            HORIZON           HORIZON-EIC-2024-ACCELERATOR-02
# 14969            HORIZON                HORIZON-INFRA-2023-TECH-01
#
#                                         subCall    fundingScheme  nature  \
# 2                                  ERC-2024-STG      HORIZON-ERC     NaN
# 3                  HORIZON-HLTH-2024-DISEASE-08      HORIZON-RIA     NaN
# 4                        HORIZON-CL5-2024-D2-01       HORIZON-IA     NaN
# 5                        HORIZON-CL5-2023-D2-02      HORIZON-RIA     NaN
# 7               HORIZON-EIC-2024-ACCELERATOR-02  HORIZON-EIC-ACC     NaN
# ...                                         ...              ...     ...
# 14957  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01      HORIZON-EIC     NaN
# 14959  HORIZON-EIC-2023-PATHFINDERCHALLENGES-01      HORIZON-EIC     NaN
# 14961        HORIZON-EIC-2023-PATHFINDEROPEN-01      HORIZON-EIC     NaN
# 14968           HORIZON-EIC-2024-ACCELERATOR-02  HORIZON-EIC-ACC     NaN
# 14969                HORIZON-INFRA-2023-TECH-01      HORIZON-RIA     NaN
#
#                                                objective    contentUpdateDate  \
# 2      "The concept of digital twins promises to revo...  2024-12-12 11:42:39
# 3      To strengthen EU's ability to fight DENV and W...  2024-12-12 11:00:45
# 4      The main mission for EPISODE is to develop a n...  2024-12-12 11:00:44
# 5      SAGELi aims to develop safer materials and cel...  2024-12-12 11:00:23
# 7      External medical devices, such as ostomy pouch...  2024-12-12 11:00:26
# ...                                                  ...                  ...
# 14957  E.T.COMPACT is aimed at reaching technology re...  2024-06-24 10:42:44
# 14959  Greenhouse gas emissions for refrigeration sys...  2024-06-17 12:50:54
# 14961  Ultra-flexible, conformable and implantable ar...  2024-09-06 17:45:33
# 14968  The energy sector is the most polluting indust...  2024-12-09 10:00:58
# 14969  The FlexRICAN project brings together three la...  2024-09-06 18:33:46
#
#           rcn           grantDoi
# 2      268016  10.3030/101165479
# 3      268032  10.3030/101191725
# 4      268027  10.3030/101191867
# 5      267735  10.3030/101147312
# 7      267755  10.3030/101188638
# ...       ...                ...
# 14957  264516  10.3030/101161603
# 14959  264057  10.3030/101161137
# 14961  258154  10.3030/101129638
# 14968  267934  10.3030/101189207
# 14969  257840  10.3030/101131516
#
# [5348 rows x 20 columns]

# %%
orgsinprojects23nogreek = orgs[orgs['projectID'].isin(projects23_no_greek['id'].tolist())]
orgsinprojects23nogreek
# Out:
#        projectID projectAcronym  organisationID       vatNumber  \
# 18     101165479       RE-TWIST       999986290    BE0407626464
# 19     101165479       RE-TWIST       999698006    BE0407185709
# 20     101191725        InFlaMe       998189947             NaN
# 21     101191725        InFlaMe       999989976     ATU57469858
# 22     101191725        InFlaMe       999582285   IT00580590180
# ...          ...            ...             ...             ...
# 97391  101131516      FlexRICAN       983194329  SE556016864201
# 97392  101131516      FlexRICAN       910554618    BE0628655020
# 97393  101131516      FlexRICAN       919998053  SE768200001801
# 97394  101131516      FlexRICAN       999997930   FR40180089013
# 97395  101131516      FlexRICAN       999470541     DE140213784
#
#                                                     name  \
# 18                         UNIVERSITE LIBRE DE BRUXELLES
# 19               VON KARMAN INSTITUTE FOR FLUID DYNAMICS
# 20     ISTITUTO ZOOPROFILATTICO SPERIMENTALE DELLA LO...
# 21                        MEDIZINISCHE UNIVERSITAET WIEN
# 22               FONDAZIONE IRCCS POLICLINICO SAN MATTEO
# ...                                                  ...
# 97391                         ALFA LAVAL TECHNOLOGIES AB
# 97392                 EUROPEAN MAGNETIC FIELD LABORATORY
# 97393                    EUROPEAN SPALLATION SOURCE ERIC
# 97394  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS
# 97395            HELMHOLTZ-ZENTRUM DRESDEN-ROSSENDORF EV
#
#                                           shortName    SME activityType  \
# 18                                              ULB  False          HES
# 19     VON KARMAN INSTITUTE FOR FLUID DYNAMICS- VKI   True          REC
# 20                                              NaN  False          REC
# 21                                              NaN  False          HES
# 22                                        IRCCS OSM  False          REC
# ...                                             ...    ...          ...
# 97391                                           NaN  False          PRC
# 97392                                  EMFL - AISBL  False          OTH
# 97393                                           NaN  False          PUB
# 97394                                          CNRS  False          REC
# 97395                                          HZDR  False          REC
#
#                              street postCode  ...  \
# 18     AVENUE FRANKLIN ROOSEVELT 50     1050  ...
# 19          Waterloose Steenweg, 72     1640  ...
# 20            VIA ANTONIO BIANCHI 9    25124  ...
# 21                   SPITALGASSE 23     1090  ...
# 22                   VIALE GOLGI 19    27100  ...
# ...                             ...      ...  ...
# 97391               RUDEBOKSVAGEN 1   221 00  ...
# 97392               RUE DU TRONE 98     1050  ...
# 97393            ODARSLOVSVAGEN 113   224 84  ...
# 97394             RUE MICHEL ANGE 3    75794  ...
# 97395      BAUTZNER LANDSTRASSE 400    01328  ...
#
#                                              contactForm    contentUpdateDate  \
# 18     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:42:39
# 19     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:42:39
# 20     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:45
# 21     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:45
# 22     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:45
# ...                                                  ...                  ...
# 97391  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 18:33:46
# 97392  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 18:33:46
# 97393  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 18:33:46
# 97394  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 18:33:46
# 97395  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 18:33:46
#
#            rcn order         role ecContribution netEcContribution  totalCost  \
# 18     1905620   2.0  participant      728750.00         728750.00     728750
# 19     1905618   1.0  coordinator      771250.00         771250.00     771250
# 20     2106939   7.0  participant      596937.50         596937.50   596937,5
# 21     1905549   4.0  participant      675940.00         675940.00     675940
# 22     1922908   1.0  coordinator      894484.25         894484.25  894484,25
# ...        ...   ...          ...            ...               ...        ...
# 97391  3099835   7.0  participant      106250.00         106250.00          0
# 97392  1965488   5.0  participant       37500.00          37500.00          0
# 97393  2720567   1.0  coordinator     1935725.00        1935725.00          0
# 97394  1905572   3.0  participant     1118375.00        1086382.00          0
# 97395  1909706   4.0  participant       78500.00          78500.00          0
#
#        endOfParticipation active
# 18                  False    NaN
# 19                  False    NaN
# 20                  False    NaN
# 21                  False    NaN
# 22                  False    NaN
# ...                   ...    ...
# 97391               False    NaN
# 97392               False    NaN
# 97393               False    NaN
# 97394               False    NaN
# 97395               False    NaN
#
# [25510 rows x 25 columns]

# %%
euroscivoc
# Out:
#        projectID        euroSciVocCode  \
# 0      101165479                     /
# 1      101165479                     /
# 2      101165479                     /
# 3      101191725                     /
# 4      101188572  /25/75/461/1239/1737
# ...          ...                   ...
# 44031  101130454                     /
# 44032  101130454                     /
# 44033  101131516                     /
# 44034  101131516                     /
# 44035  101131516                     /
#
#                                           euroSciVocPath  \
# 0      /natural sciences/physical sciences/thermodyna...
# 1      /engineering and technology/electrical enginee...
# 2      /engineering and technology/environmental engi...
# 3      /natural sciences/biological sciences/biochemi...
# 4      /engineering and technology/mechanical enginee...
# ...                                                  ...
# 44031  /natural sciences/biological sciences/ecology/...
# 44032  /engineering and technology/industrial biotech...
# 44033  /engineering and technology/environmental engi...
# 44034  /engineering and technology/electrical enginee...
# 44035  /social sciences/political sciences/government...
#
#                    euroSciVocTitle  euroSciVocDescription
# 0                   thermodynamics                    NaN
# 1                           drones                    NaN
# 2                 energy and fuels                    NaN
# 3                         proteins                    NaN
# 4                         aircraft                    NaN
# ...                            ...                    ...
# 44031                   ecosystems                    NaN
# 44032                 biomaterials                    NaN
# 44033             renewable energy                    NaN
# 44034  electric power distribution                    NaN
# 44035           government systems                    NaN
#
# [44036 rows x 5 columns]

# %%
euroscivoc_proj_no_greek = euroscivoc[euroscivoc['projectID'].isin(projects23_no_greek['id'].tolist())]

# %%
euroscivoc_proj_no_greek['euroSciVocTitle'].unique()
# Out:
# array(['thermodynamics', 'drones', 'energy and fuels', 'proteins',
#        'aircraft', 'mining and mineral processing', 'sensors', 'graphene',
#        'polymer sciences', 'geometry', 'software', 'metalloids',
#        'synthetic biology', 'biophysics', 'genomes', 'surgery',
#        'ecosystems', 'bladder cancer', 'multidrug resistance',
#        'anaesthesiology', 'databases', 'electrocatalysis', 'robotics',
#        'malaria', 'virology', 'influenza', 'semiconductivity', 'enzymes',
#        'mortality', 'alkali metals', 'materials engineering',
#        'food technology', 'grains and oilseeds', 'bioplastics',
#        'biofuels', 'pollution', 'microbiology', 'spectroscopy',
#        'fertility', 'microscopy', 'antibiotics', 'immunisation',
#        'vaccines', 'geographic information systems', 'pandemics',
#        'colors', 'bacteriology', 'obstetrics', 'epidemiology',
#        'cervical cancer', 'DNA viruses', 'alzheimer', 'entrepreneurship',
#        'biomolecules', 'immunotherapy', 'spacecraft', 'optical sensors',
#        'exoplanetology', 'rheumatology', 'pathology',
#        'cells technologies', 'aeronautical engineering', 'cryptography',
#        'cereals', 'governance', 'coal', 'topology',
#        'satellite technology', 'revolutions', 'alkaline earth metals',
#        'radiology', 'diabetes', 'superconductivity', 'ophthalmology',
#        'renewable energy', 'recycling', 'thermodynamic engineering',
#        'quantum computers', 'internet of things', 'mobile network',
#        'elections', 'essays', 'democracy', 'catalysis', 'distillation',
#        'ceramics', 'biomass', 'ultrasound', 'post-transition metals',
#        'nongovernmental organizations', 'energy conversion',
#        'productivity', 'computer security', 'carbon fibers',
#        'multiphysics', 'antivirals', 'neutrinos', 'astrophysics',
#        'employment', 'prime numbers', 'human rights violations',
#        'history', 'laser physics', 'oncology', 'DNA', 'pathophysiology',
#        'social inequalities', 'dementia', 'stroke', 'aliphatic compounds',
#        'fermentation', 'pharmacology and pharmacy',
#        'two-dimensional nanostructures', 'bureaucracy', 'internet',
#        'drug discovery', 'tuberculosis', 'quantum physics',
#        'theoretical physics', 'solid-state physics', 'implants',
#        'automation', 'psychology', 'crystals', 'optoelectronics',
#        'super resolution microscopy', 'nano-materials', 'sedimentology',
#        'deep learning', 'physiology', 'RNA', 'chromosomes',
#        'coating and films', 'photons', 'particle physics', 'dark matter',
#        'biosensors', 'pharmaceutical drugs', 'hydrocarbons',
#        'data science', 'genetics', 'personalized medicine',
#        'human trafficking', 'sustainable economy', 'forestry',
#        'government systems', 'inorganic compounds', 'mycology',
#        'machine learning', 'nanotechnology', 'spintronics',
#        'data processing', 'computational intelligence', 'photocatalysis',
#        'climatic changes', 'philosophy', 'molecular and chemical physics',
#        'cultural anthropology', 'ethnology', 'electric batteries',
#        'halogens', 'inflammatory diseases', 'immunology',
#        'computational science', 'homeostasis', 'anthropology',
#        'coronaviruses', 'gerontology', 'fruit growing',
#        'international law', 'human rights', 'parasitology', 'mutation',
#        'cell biology', 'cardiovascular diseases', 'big data',
#        'electromagnetism and electronics', 'electrolysis',
#        'plasma physics', 'separation technologies', 'marine biology',
#        'innovation management', 'remote sensing',
#        'chemical process engineering', 'microtechnology', 'amines',
#        'business and management', 'physical chemistry',
#        'sustainable agriculture', 'sustainability sciences',
#        'business models', 'animal husbandry', 'air pollution engineering',
#        'tissue engineering', 'stem cells', 'biomaterials', 'biochemistry',
#        'tropical medicine', 'ethical principles', 'hepatitis B', 'HIV',
#        'comparative morphology', 'public health',
#        'cognitive neuroscience', 'women’s studies', 'globalization',
#        'neurobiology', 'fluorescence lifetime imaging', 'ecology',
#        'entomology', 'polylactic acid', 'textiles', 'agriculture',
#        'polyhydroxyalkanoates', 'artificial intelligence',
#        'law enforcement', 'smart sensors', 'data networks', 'fibers',
#        'nutrition', 'carbohydrates', 'evolutionary biology',
#        'ocean engineering', 'wind power', 'geochemistry',
#        'analytical chemistry', 'civil society', 'library sciences',
#        'modern history', 'armed conflicts', 'judaism',
#        'mass spectrometry', 'prostate cancer', 'radar',
#        'global navigation satellite system', 'rotorcraft',
#        'inertial navigation system', 'hydrology', 'natural disasters',
#        'water management', 'data exchange', 'law', 'lubrication',
#        'soft matter physics', 'mathematical model', 'folklore',
#        'nanophotonics', 'lipids', 'condensed matter physics', 'islam',
#        'drinking water treatment processes', 'atomic physics',
#        'arteriosclerosis', 'arts', 'plate tectonics', 'proteomics',
#        'biological interactions', 'leukemia', 'game theory',
#        'gene therapy', 'fisheries', 'production economics', 'epigenetics',
#        'kidney diseases', 'journalism', 'gender equality', 'didactics',
#        'religions', 'paleoclimatology', 'crisis management',
#        'urban studies', 'fluid mechanics', 'algebraic geometry',
#        'cell polarity', 'signal processing',
#        'natural language processing', 'infectious diseases', 'hepatology',
#        'anatomy and morphology', 'computer vision', 'composites',
#        'nucleotides', 'ancient history', 'digital humanities', 'optics',
#        'quantum optics', 'mammalogy', 'obesity', 'electron microscopy',
#        'economics', 'history of literature', 'mathematics',
#        'molecular engineering', 'nuclear decay', 'fluid dynamics',
#        'numerical analysis', 'racial inequality', 'christianity',
#        'wearable medical technology ', 'magnetic resonance imaging',
#        'visual arts', 'contemporary history', 'system software',
#        'psycholinguistics', 'relational databases', 'organic chemistry',
#        'public policies', 'inclusive education', 'biogeochemistry',
#        'facial recognition', 'inflammatory bowel disease',
#        'biodiversity conservation', 'protein folding',
#        'functional analysis', 'parkinson', 'bioarchaeology',
#        'quantum field theory', 'linguistics', 'cognitive psychology',
#        'seismology', 'neutron stars', 'asteroseismology',
#        'biological sciences', 'medical and health sciences', 'epilepsy',
#        'constitutional law', 'pattern recognition', 'transition metals',
#        'data mining', 'electromagnetism', 'space exploration',
#        'natural satellites', 'geophysics', 'demography', 'graph theory',
#        'climate change adaptation', 'human migrations',
#        'manufacturing engineering', 'evolutionary ecology',
#        'reproductive biology', 'ergonomics', 'dynamical systems',
#        'computer hardware', 'developmental biology', 'drug resistance',
#        'breast cancer', 'phycology', 'eukaryotic genomes',
#        'political communication', 'political transitions',
#        'political philosophy', 'confocal microscopy', 'cardiology',
#        'public administration', 'combinatorics', 'foreign policy',
#        'structural biology', 'environmental sciences', 'nanomedicine',
#        'soft robotics', 'particle accelerator', 'fermions', 'quarks',
#        'social issues', 'lab on a chip', 'wastewater treatment processes',
#        'graft versus host disease', 'transplantation', 'ultrafast lasers',
#        'plant breeding', 'embryology', 'gender inequality',
#        'medieval history', 'nucleic acids', 'organic reactions',
#        'additive manufacturing', 'photochemistry',
#        'differential equations', 'big bang', 'physical cosmology',
#        'statistical mechanics', 'conformal field theory',
#        'complex analysis', 'statistics and probability', 'ethics',
#        'autoimmune diseases', 'supervised learning',
#        'bayesian statistics', 'dramaturgy', 'colorectal cancer',
#        'freight transport', 'melanoma', 'pharmacokinetics',
#        'oceanography', 'medical biotechnology', 'planets', 'black holes',
#        'biocatalysis', 'popular music studies', 'gender studies',
#        'arithmetics', 'algebra', 'metallurgy', 'literary criticism',
#        'social psychology', 'metabolic engineering', 'solar energy',
#        'partial differential equations', 'food safety', 'zoonosis',
#        'antibiotic resistance', 'gluons', 'corruption', 'teleology',
#        'vascular diseases', 'gravitational waves', 'supernova', 'comets',
#        'history of islam', 'criminology',
#        'science and technology studies', 'vegetable growing',
#        'schizophrenia', 'neurology', 'taxation', 'astronomy',
#        'political economy', 'commerce', 'ethnoarchaeology',
#        'archaeometry', 'eastern religions', 'social anthropology',
#        'pancreatic cancer', 'horticulture',
#        'computer and information sciences', 'architectural design',
#        'operator algebra', 'public services', 'prehistory', 'ethology',
#        'obsessive-compulsive disorder', 'physical oceanography', 'botany',
#        'family studies', 'archaeology', 'linear algebra',
#        'logarithmic functions', 'heuristic programming',
#        'bose-einstein condensates', 'alcohols', 'literature studies',
#        'geotechnics', 'planetary geology', 'multiple sclerosis',
#        'reinforcement learning', 'autonomous robots',
#        'generative artificial intelligence', 'medicinal chemistry',
#        'knowledge engineering', 'lung cancer', 'computed tomography',
#        'symplectic topology', 'algebraic topology', 'string theory',
#        'molecular biology', 'computer processors', 'virtual reality',
#        'political policies', 'health care services', 'physiotherapy',
#        'climatology', 'carbon capture engineering', 'photovoltaic',
#        'ornithology', 'terrorism', 'microfluidics', 'ethnomusicology',
#        'cinematography', 'observational astronomy', 'census',
#        'squamous cell carcinoma', 'relativistic mechanics',
#        'microelectronics', 'amyotrophic lateral sclerosis',
#        'optical astronomy', 'galaxy evolution', 'epistemology', 'nursing',
#        'sleep disorders', 'microeconomics', 'supercomputers',
#        'primatology', 'psychotherapy', 'psychiatry', 'mathematical logic',
#        'sustainable transport', 'mobile phones', 'drug allergy',
#        'RNA viruses', 'invertebrate zoology', 'asthma', 'heredity',
#        'mental processes', 'electric energy', 'natural gas', 'fuel cells',
#        'hydrogen energy', 'smart cities', 'biosphera', 'glaciology',
#        'sustainable building', 'dendrochronology', 'geology',
#        'irrigation', 'edaphology', 'compost', 'physical anthropology',
#        'quantum gases', 'behavioural psychology',
#        'semisupervised learning', 'social sciences', 'drug safety',
#        'meteorology', 'autonomous vehicles', 'discrete mathematics',
#        'health sciences', 'air traffic management', 'simulation software',
#        'cell signaling', 'planetary sciences', 'graphic design',
#        'ontology', 'medieval philosophy', 'active learning', 'agronomy',
#        'arboriculture', 'dairy', 'posttraumatic stress disorder',
#        'biosensing', 'combined heat and power', 'land management',
#        'ethical theories', 'solar thermal', 'sexual health',
#        'liver cancer', 'organ on a chip', 'ecological restoration',
#        'solid mechanics', 'chemical sciences', 'nuclear physics',
#        'nuclear energy', 'data protection', 'heat engineering', '5G',
#        'public libraries', 'bioeconomy', 'anxiety disorders',
#        'mathematical physics', 'radio astronomy', 'celestial mechanics',
#        'nonlinear optics', 'environmental engineering',
#        'transportation engineering', 'biocomposites',
#        'waste treatment processes', 'subtractive manufacturing',
#        'political violence', 'electrochemistry', 'mechatronics',
#        'swarm robotics', 'bioreactors', 'artificial bone',
#        'medical engineering', 'physical geography', 'landscape ecology',
#        'atmospheric turbulence', 'reproductive medicine',
#        'volatile organic compounds', 'natural sciences', 'bioremediation',
#        'control systems', 'diagnostic imaging', 'drainage basins',
#        'nuclear fusion', 'cavity optomechanics', 'viticulture',
#        'electric vehicles', 'automotive engineering', 'literary genres',
#        'remanufacturing', 'x-ray astronomy', 'limnology',
#        'plant protection', 'bioelectrochemistry', 'sign language',
#        'noble gases', 'earth and related environmental sciences',
#        'cartography', 'navigation systems', 'knot theory', 'sociology',
#        'paleoecology', 'histology', 'human rights law',
#        'political sciences', 'atmospheric pressure', 'hepatitis C',
#        'econometrics', 'asteroids', 'meteorites', 'cosmochemistry',
#        'extragalactic astronomy', 'digital electronics',
#        'modern philosophy', 'behavioural ecology', 'apidology',
#        'invasive species', 'apiculture', 'developmental psychology',
#        'object detection', 'social work',
#        'international protection of human rights', 'musicology',
#        'metamorphic petrology', 'sedimentary petrology',
#        'transfer learning', 'unemployment', 'animal and dairy science',
#        'LiFi', 'sexual violence', 'pedagogy', 'transport', 'sea vessels',
#        'public transport', 'mineralogy', 'phytoremediation',
#        'soil sciences', 'chemical engineering', 'microwave technology',
#        'viral genomes', 'electric power distribution', 'hydroelectricity',
#        'food packaging', 'fetal medicine', 'macroeconomics',
#        'polyurethane', 'classical mechanics', 'aromatic compounds',
#        'compressed sensing', 'software development', 'molecular genetics',
#        'genetic engineering', 'other medical sciences',
#        'social biomedical sciences', 'prokaryotic genomes',
#        'telecommunications networks', 'wave power', 'tidal energy',
#        'computational fluid dynamics', 'climatic zones', 'palaeontology',
#        'quantum chemistry', 'nanocrystals', 'regional human rights',
#        'art history', 'silviculture', 'green infrastructure',
#        'adverse drug reactions', 'critical care medicine', 'hematology',
#        'laboratory samples analysis', 'image recognition',
#        'unsupervised learning', 'molecular evolution',
#        'general language studies', 'acoustics', 'history of medicine',
#        'aldehydes', 'metaphysics', 'woodworking', 'legumes',
#        'radio frequency', 'fluid statics', 'waste management',
#        'domestic animals', 'electric power generation', 'synthetic fuels',
#        'coastal geography', 'paediatrics', 'gynaecology',
#        'health economics', 'frugal artificial intelligence', 'humanities',
#        'surgical procedures', 'nanocomposites', 'organic acids',
#        'medical genetics', 'modern and contemporary art',
#        'islamic schools', 'fodder', 'commutative algebra', 'ideologies',
#        'nanoelectronics', 'transport layer', 'coastal ecosystems',
#        'nuclear engineering', 'radiation chemistry',
#        'mathematical analysis', 'oilseeds', 'fibre optics', 'allergology',
#        'control engineering', 'stellar astronomy', 'astrochemistry',
#        'fourier analysis', 'duchenne muscular dystrophy',
#        'molecular neuroscience', 'liquid crystals', 'thermochemistry',
#        'crystallography', 'structural health monitoring', 'childbirth',
#        'liquid fuels', 'eHealth', 'cardiac arrhythmia',
#        'freshwater ecosystems', 'freshwater biology',
#        'earthquake engineering', 'telecommunications',
#        'environmental biotechnology', 'otorhinolaryngology',
#        'geological engineering', 'electrical engineering',
#        'solar radiation', 'desalination', 'structural engineering',
#        'volcanology', 'geomorphology', 'computational neuroscience',
#        'andrology', 'civil engineering', 'languages and literature',
#        'electronic engineering', 'virus mutation', '4G', 'ecohydrology',
#        'organometallic chemistry', 'pneumology', 'tribology',
#        'atmospheric circulation', 'root crops', 'physical sciences',
#        'absorption spectroscopy', 'ethnolichenology', 'cell metabolism',
#        'ichthyology', 'leptons', 'nuclear fission', 'infrared astronomy',
#        'psychoanalysis', 'speleology', 'nuclear medicine',
#        'literary theory', 'optical networks', 'industrial relations',
#        'bioinorganic chemistry', 'urology',
#        'cultural and economic geography', 'access control',
#        'radio technology', 'cetology', 'phonology', 'gastroenterology',
#        'nuclear waste management', 'e-commerce',
#        'bulk nanostructured materials', 'atmospheric sciences',
#        'monetary and finances', 'industrial crops',
#        'seismic risk management', 'epidemics prevention', 'pulsed lasers',
#        'land-based treatment', 'hydrogeology', 'electrophoresis',
#        'toxicology', 'contemporary philosophy', 'geothermal energy',
#        'calorimetry', 'protozoology', 'muscular dystrophies', 'ketones',
#        'engineering and technology', 'edge artificial Intelligence',
#        'meteors', 'cognitive radio', 'isotope geochemistry',
#        'scanning tunneling microscopy', 'family planning',
#        'hydraulic engineering', 'super-Earths', 'gas giants',
#        'concentrated solar power', 'ebola', 'muslim societies',
#        'electric power transmission', 'mechanical engineering',
#        'clinical microbiology', 'lithology', 'special education',
#        'postnatal care', 'motion analysis', 'non-relational databases',
#        'ozone depletion', 'expert systems', 'national state of emergency',
#        'media and communications', 'dietetics', 'other social sciences',
#        'industrial biotechnology', 'phonetics', 'operating systems',
#        'ecosystem-based management', 'naval engineering', 'petrology',
#        'solar physics', 'performing arts', 'odontology',
#        'occupational health', 'railroad engineering', 'world wide web',
#        'inorganic chemistry', 'e-governance', 'dermatology',
#        'video games', 'penology', 'skin cancer', 'muslim culture',
#        'troposphere', 'bioartificial liver', 'white dwarfs',
#        'molecular spintronics', 'radiochemistry',
#        'coastal and estuarine hydraulics', 'architecture engineering',
#        'diagnostic technologies', 'modeling of diseases spread',
#        'computational creativity', 'electroporation',
#        'software applications', 'biochemical engineering',
#        'knowledge organization', 'surgical specialties',
#        'intelligent transport systems', 'highway engineering',
#        'speech-language pathology', 'hybrid energy', 'petroleum',
#        'water supply systems', 'endocrinology', 'vehicle engineering',
#        'clinical neurology', 'cytology', 'robotic surgery',
#        'age inequality', 'palynology', 'underwater archaeology',
#        'substance abuse', 'veterinary sciences', 'semantic web',
#        'aerospace engineering', 'reverse osmosis',
#        'natural resources management', 'airport engineering',
#        'flood risk management', 'solar astronomy',
#        'construction engineering', 'other humanities',
#        'sustainable architecture', 'microseisms', 'higgs bosons',
#        'internet protocols', 'applied mathematics', 'electrodialysis',
#        'bioleaching'], dtype=object)

# %%
scivocpathlist = euroscivoc_proj_no_greek['euroSciVocPath'].tolist()

# %%
paths = ",".join(scivocpathlist)
print (paths)
# Out:
# /natural sciences/physical sciences/thermodynamics,/engineering and technology/electrical engineering, electronic engineering, information engineering/electronic engineering/robotics/autonomous robots/drones,/engineering and technology/environmental engineering/energy and fuels,/natural sciences/biological sciences/biochemistry/biomolecules/proteins,/engineering and technology/mechanical engineering/vehicle engineering/aerospace engineering/aircraft,/engineering and technology/environmental engineering/mining and mineral processing,/engineering and technology/electrical engineering, electronic engineering, information engineering/electronic engineering/sensors,/engineering and technology/nanotechnology/nano-materials/two-dimensional nanostructures/graphene,/natural sciences/chemical sciences/polymer sciences,/natural sciences/mathematics/pure mathematics/geometry,/engineering and technology/environmental engineering/energy and fuels,/natural sciences/computer and information sciences/software,/engineering and technology/electrical engineering, electronic engineering, information engineering/electronic engineering/robotics/autonomous robots/drones,/engineering and technology/electrical engineering, electronic engineering, information engineering/electronic engineering/sensors,/natural sciences/chemical sciences/inorganic chemistry/metalloids,/natural sciences/biological sciences/synthetic biology,/natural sciences/biological sciences/biochemistry/biomolecules/proteins,/natural sciences/biological sciences/biophysics,/natural sciences/biological sciences/genetics/genomes,/medical and health sciences/clinical medicine/surgery,/natural sciences/biological sciences/ecology/ecosystems,/medical and health sciences/clinical medicine/oncology/bladder cancer,/medical and health sciences/clinical medicine/surgery,/medical and health sciences/basic medicine/pharmacology and pharmacy/drug resistance/multidrug resistance,/medical and health sciences/clinical medicine/anaesthesiology,/natural sciences/computer and information sciences/databases,/natural sciences/chemical sciences/catalysis/electrocatalysis,/engineering and technology/electrical engineering, electronic engineering, information engineering/electronic engineering/robotics,/engineering and technology/environmental engineering/energy and fuels,/medical and health sciences/health sciences/infectious diseases/malaria,/natural sciences/biological sciences/microbiology/virology,/medical and health sciences/health sciences/infectious diseases/RNA viruses/influenza,/natural sciences/physical sciences/electromagnetism and electronics/semiconductivity,/natural sciences/biological sciences/biochemistry/biomolecules/proteins/enzymes,/social sciences/sociology/demography/mortality,/natural sciences/biological sciences/microbiology/virology,/natural sciences/biological sciences/biochemistry/biomolecules/proteins,/natural sciences/chemical sciences/inorganic chemistry/alkali metals,/engineering and technology/materials engineering,/engineering and technology/electrical engineering, electronic engineering, information engineering/electronic engineering/sensors,/engineering and technology/other engineering and technologies/food technology,/agricultural sciences/agriculture, forestry, and fisheries/agriculture/grains and oilseeds,/engineering and technology/environmental engineering/energy and fuels,/engineering and technology/industrial biotechnology/biomaterials/bioplastics,/engineering and technology/industrial biotechnology/biomaterials/biofuels,/natural sciences/earth and related environmental sciences/environmental sciences/pollution,/engineering and technology/environmental engineering/energy and fuels,/natural sciences/biological sciences/microbiology,/engineering and technology/electrical engineering, electronic engineering, information engineering/electronic engineering/sensors,/natural sciences/physical sciences/optics/spectroscopy,/social sciences/sociology/demography/mortality,/natu ...

# %%
paths = paths.replace('/',',')
paths = paths.replace(',,',',')

# %%
paths
# Out:
# ',natural sciences,physical sciences,thermodynamics,engineering and technology,electrical engineering, electronic engineering, information engineering,electronic engineering,robotics,autonomous robots,drones,engineering and technology,environmental engineering,energy and fuels,natural sciences,biological sciences,biochemistry,biomolecules,proteins,engineering and technology,mechanical engineering,vehicle engineering,aerospace engineering,aircraft,engineering and technology,environmental engineering,mining and mineral processing,engineering and technology,electrical engineering, electronic engineering, information engineering,electronic engineering,sensors,engineering and technology,nanotechnology,nano-materials,two-dimensional nanostructures,graphene,natural sciences,chemical sciences,polymer sciences,natural sciences,mathematics,pure mathematics,geometry,engineering and technology,environmental engineering,energy and fuels,natural sciences,computer and information sciences,software,engineering and technology,electrical engineering, electronic engineering, information engineering,electronic engineering,robotics,autonomous robots,drones,engineering and technology,electrical engineering, electronic engineering, information engineering,electronic engineering,sensors,natural sciences,chemical sciences,inorganic chemistry,metalloids,natural sciences,biological sciences,synthetic biology,natural sciences,biological sciences,biochemistry,biomolecules,proteins,natural sciences,biological sciences,biophysics,natural sciences,biological sciences,genetics,genomes,medical and health sciences,clinical medicine,surgery,natural sciences,biological sciences,ecology,ecosystems,medical and health sciences,clinical medicine,oncology,bladder cancer,medical and health sciences,clinical medicine,surgery,medical and health sciences,basic medicine,pharmacology and pharmacy,drug resistance,multidrug resistance,medical and health sciences,clinical medicine,anaesthesiology,natural sciences,computer and information sciences,databases,natural sciences,chemical sciences,catalysis,electrocatalysis,engineering and technology,electrical engineering, electronic engineering, information engineering,electronic engineering,robotics,engineering and technology,environmental engineering,energy and fuels,medical and health sciences,health sciences,infectious diseases,malaria,natural sciences,biological sciences,microbiology,virology,medical and health sciences,health sciences,infectious diseases,RNA viruses,influenza,natural sciences,physical sciences,electromagnetism and electronics,semiconductivity,natural sciences,biological sciences,biochemistry,biomolecules,proteins,enzymes,social sciences,sociology,demography,mortality,natural sciences,biological sciences,microbiology,virology,natural sciences,biological sciences,biochemistry,biomolecules,proteins,natural sciences,chemical sciences,inorganic chemistry,alkali metals,engineering and technology,materials engineering,engineering and technology,electrical engineering, electronic engineering, information engineering,electronic engineering,sensors,engineering and technology,other engineering and technologies,food technology,agricultural sciences,agriculture, forestry, and fisheries,agriculture,grains and oilseeds,engineering and technology,environmental engineering,energy and fuels,engineering and technology,industrial biotechnology,biomaterials,bioplastics,engineering and technology,industrial biotechnology,biomaterials,biofuels,natural sciences,earth and related environmental sciences,environmental sciences,pollution,engineering and technology,environmental engineering,energy and fuels,natural sciences,biological sciences,microbiology,engineering and technology,electrical engineering, electronic engineering, information engineering,electronic engineering,sensors,natural sciences,physical sciences,optics,spectroscopy,social sciences,sociology,demography,mortality,natural sciences,chemical sciences,inorganic chemistry ...

# %%
refs = paths.split(',')
refs = set(refs)
refs = [r.strip() for r in refs]
refs
# Out:
# ['',
#  'anatomy and morphology',
#  'developmental psychology',
#  'naval engineering',
#  'andrology',
#  'developmental biology',
#  'smart sensors',
#  'melanoma',
#  'immunotherapy',
#  'supernova',
#  'geometry',
#  'mental processes',
#  '5G',
#  'linear algebra',
#  'aliphatic compounds',
#  'geotechnics',
#  'literary genres',
#  'asthma',
#  'transport layer',
#  'forestry',
#  'phonology',
#  'noble gases',
#  'biosphera',
#  'odontology',
#  'islamic schools',
#  'medical and health sciences',
#  'fermions',
#  'zoology',
#  'microfluidics',
#  'hydrogen energy',
#  'synthetic biology',
#  'medical engineering',
#  'stellar astronomy',
#  'mathematical analysis',
#  'molecular genetics',
#  'textiles',
#  'epidemics prevention',
#  'dermatology',
#  'occupational health',
#  'neutrinos',
#  'infrared astronomy',
#  'business and management',
#  'environmental sciences',
#  'geographic information systems',
#  'digital humanities',
#  'social work',
#  'hepatitis C',
#  'inflammatory diseases',
#  'psychiatry',
#  'green infrastructure',
#  '4G',
#  'sleep disorders',
#  'nuclear waste management',
#  'wearable medical technology',
#  'frugal artificial intelligence',
#  'biocatalysis',
#  'theoretical physics',
#  'immunology',
#  'computational neuroscience',
#  'tidal energy',
#  'transfer learning',
#  'tuberculosis',
#  'water management',
#  'biological interactions',
#  'natural satellites',
#  'hydrogeology',
#  'bulk nanostructured materials',
#  'superconductivity',
#  'ethics',
#  'structural biology',
#  'tissue engineering',
#  'ethnology',
#  'radio technology',
#  'photochemistry',
#  'optical astronomy',
#  'e-commerce',
#  'judaism',
#  'educational sciences',
#  'world wide web',
#  'ebola',
#  'solid mechanics',
#  'general language studies',
#  'quantum chemistry',
#  'laboratory samples analysis',
#  'paediatrics',
#  'physical chemistry',
#  'aldehydes',
#  'human migrations',
#  'endocrinology',
#  'coronaviruses',
#  'crystals',
#  'epidemiology',
#  'social geography',
#  'environmental engineering',
#  'signal processing',
#  'comparative morphology',
#  'other engineering and technologies',
#  'nanophotonics',
#  'relativistic mechanics',
#  'urology',
#  'sensors',
#  'sustainable agriculture',
#  'environmental biotechnology',
#  'multiphysics',
#  'plate tectonics',
#  'logarithmic functions',
#  'x-ray astronomy',
#  'railroad engineering',
#  'tropical medicine',
#  'quantum optics',
#  'bladder cancer',
#  'entrepreneurship',
#  'nutrition',
#  'edge artificial Intelligence',
#  'radiology',
#  'aeronautical engineering',
#  'arithmetics',
#  'LiFi',
#  'biological behavioural sciences',
#  'allergology',
#  'languages and literature',
#  'human rights violations',
#  'leukemia',
#  'pharmaceutical drugs',
#  'chemical process engineering',
#  'electric power distribution',
#  'modern philosophy',
#  'molecular and chemical physics',
#  'political violence',
#  'ceramics',
#  'homeostasis',
#  'pedagogy',
#  'higgs bosons',
#  'monetary and finances',
#  'satellite technology',
#  'algebra',
#  'international law',
#  'public transport',
#  'gravitational waves',
#  'pharmacology and pharmacy',
#  'fluid mechanics',
#  'history of medicine',
#  'childbirth',
#  'genetic engineering',
#  'viral genomes',
#  'telecommunications',
#  'dementia',
#  'energy conversion',
#  'radar',
#  'internet of things',
#  'science and technology studies',
#  'econometrics',
#  'liquid crystals',
#  'bayesian statistics',
#  'bioleaching',
#  'popular music studies',
#  'cardiology',
#  'cultural and economic geography',
#  'volcanology',
#  'social anthropology',
#  'mineralogy',
#  'phytoremediation',
#  'biochemistry',
#  'statistical mechanics',
#  'library sciences',
#  'infectious diseases',
#  'political sciences',
#  'cryptography',
#  'ultrasound',
#  'mortality',
#  'fuel cells',
#  'public libraries',
#  'alkali metals',
#  'behavioural ecology',
#  'dietetics',
#  'reverse osmosis',
#  'two-dimensional nanostructures',
#  'malaria',
#  'sustainable architecture',
#  'information engineering',
#  'nuclear physics',
#  'atmospheric circulation',
#  'sustainable economy',
#  'bioremediation',
#  'business models',
#  'posttraumatic stress disorder',
#  'soft robotics',
#  'comets',
#  'soft matter physics',
#  'analytical chemistry',
#  'gluons',
#  'thermochemistry',
#  'nanoelectronics',
#  'aircraft',
#  'drainage basins',
#  'medical biotechnology',
#  'industrial crops',
#  'reinforcement learning',
#  'power engineering',
#  'christianity',
#  'marine biology',
#  'bioprocessing technologies',
#  'neurobiology',
#  'physical oceanography',
#  'nanocomposites',
#  'access control',
#  'automation',
#  'apiculture',
#  'computational science',
#  'dairy',
#  'synthetic fuels',
#  'unemployment',
#  'vehicle engineering',
#  'antibiotic resistance',
#  'photocatalysis',
#  'woodworking',
#  'biofuels',
#  'civil engineering',
#  'zoonosis',
#  'political economy',
#  'mechatronics',
#  'fertility',
#  'gene therapy',
#  'arteriosclerosis',
#  'surgical procedures',
#  'surgery',
#  'political transitions',
#  'toxicology',
#  'cosmochemistry',
#  'government systems',
#  'data science',
#  'sea vessels',
#  'cervical cancer',
#  'cultural anthropology',
#  'electrolysis',
#  'lubrication',
#  'terrorism',
#  'solar thermal',
#  'angiology',
#  'transition metals',
#  'limnology',
#  'visual arts',
#  'palaeontology',
#  'composites',
#  'islam',
#  'electron microscopy',
#  'medical laboratory technology',
#  'mobile network',
#  'marine energy',
#  'ultrafast lasers',
#  'virus mutation',
#  'age inequality',
#  'digital electronics',
#  'metaphysics',
#  'fetal medicine',
#  'volatile organic compounds',
#  'electric power transmission',
#  'spintronics',
#  'control systems',
#  'nucleotides',
#  'molecular biology',
#  'eHealth',
#  'clinical medicine',
#  'computer vision',
#  'pulsed lasers',
#  'nuclear medicine',
#  'recycling',
#  'hepatitis B',
#  'relational databases',
#  'drug safety',
#  'gynaecology',
#  'meteorology',
#  'atmospheric turbulence',
#  'radiation chemistry',
#  'conformal field theory',
#  'other medical sciences',
#  'DNA viruses',
#  'lab on a chip',
#  'rotorcraft',
#  'ergonomics',
#  'colors',
#  'computational intelligence',
#  'data networks',
#  'planetary sciences',
#  'solar energy',
#  'mining and mineral processing',
#  'non-relational databases',
#  'condensed matter physics',
#  'nonlinear optics',
#  'black holes',
#  'nuclear decay',
#  'sustainable transport',
#  'invasive species',
#  'exoplanetology',
#  'and fisheries',
#  'gastroenterology',
#  'airport engineering',
#  'troposphere',
#  'thermodynamic engineering',
#  'ontology',
#  'mathematical model',
#  'bioreactors',
#  'solar physics',
#  'e-governance',
#  'underwater archaeology',
#  'stem cells',
#  'ecology',
#  'object detection',
#  'coal',
#  'muscular dystrophies',
#  'sexual health',
#  'astronautical engineering',
#  'obstetrics',
#  'asteroseismology',
#  'molecular evolution',
#  'gerontology',
#  'microelectronics',
#  'mutation',
#  'space exploration',
#  'software development',
#  'biodiversity conservation',
#  'civil society',
#  'land-based treatment',
#  'petroleum',
#  'productivity',
#  'graph theory',
#  'fodder',
#  'urban studies',
#  'computer processors',
#  'biocomposites',
#  'forestry',
#  'vegetable growing',
#  'invertebrate zoology',
#  'contemporary philosophy',
#  'fermentation',
#  'atmospheric sciences',
#  'cells technologies',
#  'nursing',
#  'architecture engineering',
#  'gender equality',
#  'cavity optomechanics',
#  'fluid statics',
#  'classical mechanics',
#  'RNA',
#  'natural language processing',
#  'emergency medicine',
#  'scanning tunneling microscopy',
#  'electrical engineering',
#  'root crops',
#  'functional analysis',
#  'isotope geochemistry',
#  'combined heat and power',
#  'virtual reality',
#  'photovoltaic',
#  'artificial intelligence',
#  'plant breeding',
#  'automotive engineering',
#  'commerce',
#  'botany',
#  'glaciology',
#  'enzymes',
#  'mass spectrometry',
#  'aromatic compounds',
#  'nuclear chemistry',
#  'epistemology',
#  'electric power generation',
#  'flood risk management',
#  'plasma physics',
#  'women’s studies',
#  'partial differential equations',
#  'active learning',
#  'remanufacturing',
#  'public policies',
#  'paleoecology',
#  'construction engineering',
#  'antibiotics',
#  'drug allergy',
#  'reproductive medicine',
#  'organic acids',
#  'dramaturgy',
#  'quantum gases',
#  'ethics and religion',
#  'transportation engineering',
#  'schizophrenia',
#  'animal and dairy science',
#  'drug discovery',
#  'anxiety disorders',
#  'ethnolichenology',
#  'differential equations',
#  'concentrated solar power',
#  'nuclear energy',
#  'fibre optics',
#  'evolutionary biology',
#  'inertial navigation system',
#  'hydrology',
#  'multidrug resistance',
#  'social biomedical sciences',
#  'vaccines',
#  'other humanities',
#  'kidney diseases',
#  'agricultural biotechnology',
#  'planets',
#  'planetary geology',
#  'ideologies',
#  'organ on a chip',
#  'history of philosophy',
#  'facial recognition',
#  'grains and oilseeds',
#  'physical anthropology',
#  'religions',
#  'photons',
#  'history of literature',
#  'symplectic topology',
#  'paleoclimatology',
#  'economics and business',
#  'ethnomusicology',
#  'public services',
#  'cardiovascular diseases',
#  'wave power',
#  'complex analysis',
#  'sexual violence',
#  'electrodialysis',
#  'distillation',
#  'political communication',
#  'heat engineering',
#  'coastal geography',
#  'lipids',
#  'absorption spectroscopy',
#  'sign language',
#  'desalination',
#  'human rights',
#  'internet',
#  'palynology',
#  'macroeconomics',
#  'stroke',
#  'linguistics',
#  'special education',
#  'veterinary sciences',
#  'muslim culture',
#  'spacecraft',
#  'genomes',
#  'liver cancer',
#  'public health',
#  'water supply systems',
#  'nucleic acids',
#  'simulation software',
#  'artificial bone',
#  'materials engineering',
#  'humanities',
#  'big data',
#  'psycholinguistics',
#  'observational astronomy',
#  'sustainable building',
#  'molecular spintronics',
#  'satellite navigation system',
#  'obesity',
#  'substance abuse',
#  'compost',
#  'microbiology',
#  'crystallography',
#  'bacteriology',
#  'information engineering',
#  'law',
#  'ethical theories',
#  'atmospheric pressure',
#  'quantum physics',
#  'medieval history',
#  'arts',
#  'architectural design',
#  'irrigation',
#  'petrology',
#  'electroporation',
#  'art history',
#  'mycology',
#  'gas giants',
#  'intelligent transport systems',
#  'knowledge engineering',
#  'arboriculture',
#  'hepatology',
#  'foreign policy',
#  'biomolecules',
#  'medical genetics',
#  'constitutional law',
#  'carbon fibers',
#  'skin cancer',
#  'production economics',
#  'catalysis',
#  'horticulture',
#  'tribology',
#  'reproductive biology',
#  'data protection',
#  'health sciences',
#  'confocal microscopy',
#  'law enforcement',
#  'radio astronomy',
#  'autonomous robots',
#  'agriculture',
#  'electric batteries',
#  'psychotherapy',
#  'globalization',
#  'organic chemistry',
#  'geochemistry',
#  'atomic physics',
#  'bioelectrochemistry',
#  'cell polarity',
#  'air pollution engineering',
#  'influenza',
#  'graphene',
#  'bioarchaeology',
#  'metamorphic petrology',
#  'heuristic programming',
#  'halogens',
#  'ecohydrology',
#  'nano-materials',
#  'rheumatology',
#  'motion analysis',
#  'bureaucracy',
#  'land management',
#  'coating and films',
#  'waste management',
#  'unsupervised learning',
#  'regional human rights',
#  'psychology',
#  'criminology',
#  'astronomy',
#  'neutron stars',
#  'electromagnetism and electronics',
#  'ecosystems',
#  'leptons',
#  'muslim societies',
#  'postnatal care',
#  'racial inequality',
#  'governance',
#  'image recognition',
#  'nanotechnology',
#  'white dwarfs',
#  'meteors',
#  'microseisms',
#  'innovation management',
#  'metalloids',
#  'social inequalities',
#  'carbon capture engineering',
#  'waste treatment processes',
#  'mathematical logic',
#  'vascular diseases',
#  'cardiac arrhythmia',
#  'media and communications',
#  'solar astronomy',
#  'electrochemistry',
#  'sociology',
#  'nongovernmental organizations',
#  'literature studies',
#  'natural disasters',
#  'human rights law',
#  'clinical neurology',
#  'inorganic chemistry',
#  'phonetics',
#  'parkinson',
#  'radiochemistry',
#  'domestic animals',
#  'critical care medicine',
#  'computational creativity',
#  'didactics',
#  'physiotherapy',
#  'agronomy',
#  'phycology',
#  'mechanical engineering',
#  'hydrocarbons',
#  'carbohydrates',
#  'journalism',
#  'prokaryotic genomes',
#  'drones',
#  'cognitive radio',
#  'computer and information sciences',
#  'eastern religions',
#  'software applications',
#  'spectroscopy',
#  'pure mathematics',
#  'semisupervised learning',
#  'nuclear engineering',
#  'super resolution microscopy',
#  'history',
#  'basic medicine',
#  'earth and related environmental sciences',
#  'social issues',
#  'biosensors',
#  'organic reactions',
#  'soil sciences',
#  'water treatment processes',
#  'algebraic topology',
#  'giant planets',
#  'astrochemistry',
#  'ecosystem-based management',
#  'mobile phones',
#  'oncology',
#  'sustainability sciences',
#  'transport',
#  'biological sciences',
#  'cognitive psychology',
#  'freshwater biology',
#  'earthquake engineering',
#  'cereals',
#  'electric vehicles',
#  'plant protection',
#  'apidology',
#  'musicology',
#  'radio frequency',
#  'proteins',
#  'mathematical physics',
#  'metabolic engineering',
#  'biomass',
#  'philosophy',
#  'drug resistance',
#  'agricultural sciences',
#  'ethnoarchaeology',
#  'machine learning',
#  'geothermal energy',
#  'bioinorganic chemistry',
#  'pharmacokinetics',
#  'seismic risk management',
#  'nuclear fission',
#  'cell metabolism',
#  'bioartificial liver',
#  'inclusive education',
#  'penology',
#  'oilseeds',
#  'asteroids',
#  'thermodynamics',
#  'autonomous vehicles',
#  'medieval philosophy',
#  'seismology',
#  'software',
#  'coastal ecosystems',
#  'computational fluid dynamics',
#  'robotics',
#  'anthropology',
#  'human trafficking',
#  'quantum computers',
#  'ophthalmology',
#  'entomology',
#  'natural gas',
#  'applied mathematics',
#  'pathophysiology',
#  'social psychology',
#  'climatic zones',
#  'physiology',
#  'algebraic geometry',
#  'pancreatic cancer',
#  'literary criticism',
#  'optical sensors',
#  'computer hardware',
#  'meteorites',
#  'engineering and technology',
#  'aerospace engineering',
#  'physical geography',
#  'fisheries',
#  'cell biology',
#  'edaphology',
#  'family planning',
#  'autoimmune diseases',
#  'compressed sensing',
#  'natural resources management',
#  'internet protocols',
#  'telecommunications networks',
#  'cell signaling',
#  'operating systems',
#  'organometallic chemistry',
#  'navigation systems',
#  'eukaryotic genomes',
#  'freight transport',
#  'water engineering',
#  'gender studies',
#  'data mining',
#  'particle accelerator',
#  'biochemical engineering',
#  'game theory',
#  'semiconductivity',
#  'dendrochronology',
#  'history of islam',
#  'subtractive manufacturing',
#  'social sciences',
#  'cetology',
#  'molecular neuroscience',
#  'polymer sciences',
#  'energy and fuels',
#  'astrophysics',
#  'structural health monitoring',
#  'polylactic acid',
#  'census',
#  'international protection of human rights',
#  'quantum field theory',
#  'prostate cancer',
#  'robotic surgery',
#  'anaesthesiology',
#  'epilepsy',
#  'industrial relations',
#  'geology',
#  'pathology',
#  'ecological restoration',
#  'ancient history',
#  'acoustics',
#  'electronic engineering',
#  'physical sciences',
#  'ozone depletion',
#  'protozoology',
#  'colorectal cancer',
#  'genetics',
#  'remote sensing',
#  'optics',
#  'parasitology',
#  'alcohols',
#  'knowledge organization',
#  'laser physics',
#  'topology',
#  'post-transition metals',
#  'mammalogy',
#  'nephrology',
#  'air traffic management',
#  'microscopy',
#  'databases',
#  'squamous cell carcinoma',
#  'teleology',
#  'viticulture',
#  'microwave technology',
#  'manufacturing engineering',
#  'employment',
#  'legumes',
#  'electric energy',
#  'hydroelectricity',
#  'revolutions',
#  'swarm robotics',
#  'climatology',
#  'geological engineering',
#  'statistics and probability',
#  'antivirals',
#  'archaeology',
#  'system software',
#  'family studies',
#  'diabetes',
#  'histology',
#  'super-Earths',
#  'molecular engineering',
#  'fourier analysis',
#  'ketones',
#  'microeconomics',
#  'immunisation',
#  'expert systems',
#  'nanomedicine',
#  'lung cancer',
#  'ocean engineering',
#  'health care services',
#  'inflammatory bowel disease',
#  'fibers',
#  'geophysics',
#  'other social sciences',
#  'optoelectronics',
#  'climate change adaptation',
#  'national state of emergency',
#  'dynamical systems',
#  'literary theory',
#  'oceanography',
#  'food safety',
#  'structural engineering',
#  'demography',
#  'cytology',
#  'surgical specialties',
#  'diagnostic imaging',
#  'liquid fuels',
#  'physical cosmology',
#  'deep learning',
#  'protein folding',
#  'amyotrophic lateral sclerosis',
#  'industrial biotechnology',
#  'history and archaeology',
#  'commutative algebra',
#  'speech-language pathology',
#  'obsessive-compulsive disorder',
#  'dark matter',
#  'modern and contemporary art',
#  'electrophoresis',
#  'natural sciences',
#  'control engineering',
#  'behavioural psychology',
#  'DNA',
#  'fluorescence lifetime imaging',
#  'modern history',
#  'alkaline earth metals',
#  'breast cancer',
#  'pneumology',
#  'primatology',
#  'particle physics',
#  'virology',
#  'inorganic compounds',
#  'string theory',
#  'celestial mechanics',
#  'archaeometry',
#  'political policies',
#  'folklore',
#  'bioeconomy',
#  'coastal and estuarine hydraulics',
#  'multiple sclerosis',
#  'highway engineering',
#  'biophysics',
#  'chemical engineering',
#  'RNA viruses',
#  'electrocatalysis',
#  'alzheimer',
#  'armed conflicts',
#  'fossil energy',
#  'heredity',
#  'food packaging',
#  'epigenetics',
#  'computed tomography',
#  'clinical microbiology',
#  'cartography',
#  'big bang',
#  'hybrid energy',
#  'biosensing',
#  'prime numbers',
#  'smart cities',
#  'personalized medicine',
#  'performing arts',
#  'galaxy evolution',
#  'operator algebra',
#  'food technology',
#  'hematology',
#  'pollution',
#  'contemporary history',
#  'evolutionary ecology',
#  'ornithology',
#  'urban engineering',
#  'generative artificial intelligence',
#  'climatic changes',
#  'magnetic resonance imaging',
#  'numerical analysis',
#  'separation technologies',
#  'public administration',
#  'discrete mathematics',
#  'transport planning',
#  'prehistory',
#  'supercomputers',
#  'silviculture',
#  'bioplastics',
#  'essays',
#  'global navigation satellite system',
#  'fruit growing',
#  'biological morphology',
#  'sedimentary petrology',
#  'additive manufacturing',
#  'crisis management',
#  'bose-einstein condensates',
#  'combinatorics',
#  'sedimentology',
#  'ethical principles',
#  'polyurethane',
#  'lithology',
#  'chemical sciences',
#  'amines',
#  'semantic web',
#  'corruption',
#  'HIV',
#  'nanocrystals',
#  'electronic engineering',
#  'speleology',
#  'implants',
#  'optical networks',
#  'biomaterials',
#  'elections',
#  'cognitive neuroscience',
#  'economics',
#  'taxation',
#  'health economics',
#  'computer security',
#  'wastewater treatment processes',
#  'mathematics',
#  'metallurgy',
#  'animal husbandry',
#  'wind power',
#  'extragalactic astronomy',
#  'nuclear fusion',
#  'embryology',
#  'neurology',
#  'ethology',
#  'adverse drug reactions',
#  'quarks',
#  'video games',
#  'data processing',
#  'supervised learning',
#  'electromagnetism',
#  'pandemics',
#  'duchenne muscular dystrophy',
#  'solid-state physics',
#  'graft versus host disease',
#  'geomorphology',
#  'ichthyology',
#  'political philosophy',
#  'cinematography',
#  'graphic design',
#  'knot theory',
#  'democracy',
#  'calorimetry',
#  'fluid dynamics',
#  'microtechnology',
#  'pattern recognition',
#  'diagnostic technologies',
#  'hydraulic engineering',
#  'drinking water treatment processes',
#  'transplantation',
#  'freshwater ecosystems',
#  'renewable energy',
#  'chromosomes',
#  'biogeochemistry',
#  'medicinal chemistry',
#  'modeling of diseases spread',
#  'proteomics',
#  'landscape ecology',
#  'otorhinolaryngology',
#  'gender inequality',
#  'galactic astronomy',
#  'data exchange',
#  'polyhydroxyalkanoates',
#  'psychoanalysis',
#  'solar radiation']

# %%
print (len(refs))
# Out:
# 923

# %%
projects23_no_greek['fundingScheme'].unique()
# Out:
# array(['HORIZON-ERC', 'HORIZON-RIA', 'HORIZON-IA', 'HORIZON-EIC-ACC',
#        'HORIZON-ERC-SYG', 'HORIZON-JU-RIA', 'HORIZON-ERC-POC',
#        'HORIZON-TMA-MSCA-PF-EF', 'HORIZON-TMA-MSCA-PF-GF',
#        'HORIZON-TMA-MSCA-SE', 'HORIZON-CSA', 'HORIZON-JU-CSA',
#        'EURATOM-CSA', 'HORIZON-JU-IA', 'HORIZON-COFUND', 'ERC',
#        'EURATOM-IA', 'HORIZON-TMA-MSCA-Cofund-D', 'HORIZON-TMA-MSCA-DN',
#        'HORIZON-TMA-MSCA-Cofund-P', 'MSCA-PF', 'HORIZON-AG-UN',
#        'HORIZON-TMA-MSCA-DN-JD', 'HORIZON-TMA-MSCA-DN-ID', 'EURATOM-RIA',
#        'RIA', 'EURATOM-COFUND', 'HORIZON-EIC', 'HORIZON-EIC-ACC-BF'],
#       dtype=object)

# %%
projects_filt = projects23_no_greek[projects23_no_greek['fundingScheme'].isin(['HORIZON-RIA','HORIZON-IA','HORIZON-CSA','RIA'])]

# %%
projects_filt
# Out:
#               id         acronym  status  \
# 3      101191725         InFlaMe  SIGNED
# 4      101191867         EPISODE  SIGNED
# 5      101147312          SAGELI  SIGNED
# 23     101157146     EUmetriosis  SIGNED
# 38     101155852        PIPELINE  SIGNED
# ...          ...             ...     ...
# 14059  101165966       InnoMatch  SIGNED
# 14444  101167739  EIC ACCESSplus  SIGNED
# 14571  101160467        InnoNext  SIGNED
# 14875  101194408           ACORN  SIGNED
# 14969  101131516       FlexRICAN  SIGNED
#
#                                                    title  startDate  \
# 3      Counter-acting the pandemic potential of flavi... 2025-01-01
# 4      European Produced sustaInable SODium-ion battE... 2024-12-01
# 5      ADVANCED SAFER MATERIALS AND HIGH PERFORMING C... 2025-01-01
# 23     EUmetriosis: Transforming endometriosis care i... 2025-01-01
# 38     Pregnancy and Infant PrEparedness pLatform IN ... 2025-01-01
# ...                                                  ...        ...
# 14059                    Matching innovators with buyers 2024-09-01
# 14444  Advancing Cross-border Coaching and Economic s... 2024-08-01
# 14571  The Next Generation Innovation Talents' initia... 2024-08-01
# 14875  Advancing Circular Economy with Bio-Based Solu... 2024-11-01
# 14969    Flexibility in RIs for global CArbon Neutrality 2024-03-01
#
#          endDate   totalCost ecMaxContribution   legalBasis  \
# 3     2028-12-31   7995922,4         7995922,4  HORIZON.2.1
# 4     2028-05-31           0        6597981,39  HORIZON.2.5
# 5     2027-12-31  4975670,75        4975669,75  HORIZON.2.5
# 23    2029-12-31           0        6981844,36  HORIZON.2.1
# 38    2028-12-31           0        9999975,25  HORIZON.2.1
# ...          ...         ...               ...          ...
# 14059 2027-08-31     2999875           2999875  HORIZON.3.1
# 14444 2026-07-31     4499625           4499625  HORIZON.3.1
# 14571 2026-07-31     3986000           3986000  HORIZON.3.1
# 14875 2026-08-31           0             50000  HORIZON.3.1
# 14969 2027-02-28           0         4991962,5  HORIZON.1.3
#
#                                           topics ecSignatureDate  \
# 3                HORIZON-HLTH-2024-DISEASE-08-20      2024-12-02
# 4                      HORIZON-CL5-2024-D2-01-02      2024-11-29
# 5                      HORIZON-CL5-2023-D2-02-02      2024-11-18
# 23     HORIZON-HLTH-2024-DISEASE-03-14-two-stage      2024-11-29
# 38     HORIZON-HLTH-2024-DISEASE-03-11-two-stage      2024-11-29
# ...                                          ...             ...
# 14059            HORIZON-EIC-2023-INNOVPRO-01-01      2024-07-09
# 14444            HORIZON-EIC-2023-PARTNERS-01-01      2024-07-09
# 14571             HORIZON-EIC-2023-TALENTS-01-01      2024-07-05
# 14875            HORIZON-EIC-2024-BOOSTER-IBA-01      2024-10-25
# 14969              HORIZON-INFRA-2023-TECH-01-01      2023-10-23
#
#       frameworkProgramme                              masterCall  \
# 3                HORIZON            HORIZON-HLTH-2024-DISEASE-08
# 4                HORIZON                  HORIZON-CL5-2024-D2-01
# 5                HORIZON                  HORIZON-CL5-2023-D2-02
# 23               HORIZON  HORIZON-HLTH-2024-DISEASE-03-two-stage
# 38               HORIZON  HORIZON-HLTH-2024-DISEASE-03-two-stage
# ...                  ...                                     ...
# 14059            HORIZON            HORIZON-EIC-2023-INNOVPRO-01
# 14444            HORIZON            HORIZON-EIC-2023-PARTNERS-01
# 14571            HORIZON             HORIZON-EIC-2023-TALENTS-01
# 14875            HORIZON         HORIZON-EIC-2024-BOOSTER-IBA-01
# 14969            HORIZON              HORIZON-INFRA-2023-TECH-01
#
#                                       subCall fundingScheme  nature  \
# 3                HORIZON-HLTH-2024-DISEASE-08   HORIZON-RIA     NaN
# 4                      HORIZON-CL5-2024-D2-01    HORIZON-IA     NaN
# 5                      HORIZON-CL5-2023-D2-02   HORIZON-RIA     NaN
# 23     HORIZON-HLTH-2024-DISEASE-03-two-stage   HORIZON-RIA     NaN
# 38     HORIZON-HLTH-2024-DISEASE-03-two-stage   HORIZON-RIA     NaN
# ...                                       ...           ...     ...
# 14059            HORIZON-EIC-2023-INNOVPRO-01   HORIZON-CSA     NaN
# 14444            HORIZON-EIC-2023-PARTNERS-01   HORIZON-CSA     NaN
# 14571             HORIZON-EIC-2023-TALENTS-01   HORIZON-CSA     NaN
# 14875         HORIZON-EIC-2024-BOOSTER-IBA-01   HORIZON-CSA     NaN
# 14969              HORIZON-INFRA-2023-TECH-01   HORIZON-RIA     NaN
#
#                                                objective    contentUpdateDate  \
# 3      To strengthen EU's ability to fight DENV and W...  2024-12-12 11:00:45
# 4      The main mission for EPISODE is to develop a n...  2024-12-12 11:00:44
# 5      SAGELi aims to develop safer materials and cel...  2024-12-12 11:00:23
# 23     Despite its high prevalence (10% of women and ...  2024-12-12 10:57:23
# 38     Recent epidemics have highlighted how infectio...  2024-12-12 10:52:37
# ...                                                  ...                  ...
# 14059  "Overcoming the challenge of finding initial c...  2024-07-24 17:09:52
# 14444  EIC-ACCESS+ mission is to enable EIC Awardees ...  2024-07-16 15:26:50
# 14571  In today's fast-paced global landscape, innova...  2024-07-23 10:05:18
# 14875  ACORN researches and develops business models ...  2024-11-01 17:52:31
# 14969  The FlexRICAN project brings together three la...  2024-09-06 18:33:46
#
#           rcn           grantDoi
# 3      268032  10.3030/101191725
# 4      268027  10.3030/101191867
# 5      267735  10.3030/101147312
# 23     268009  10.3030/101157146
# 38     267995  10.3030/101155852
# ...       ...                ...
# 14059  264818  10.3030/101165966
# 14444  264735  10.3030/101167739
# 14571  264823  10.3030/101160467
# 14875  267174  10.3030/101194408
# 14969  257840  10.3030/101131516
#
# [1022 rows x 20 columns]

# %%
projects_ = projects_filt[['id','acronym','title','startDate','endDate','totalCost','legalBasis','topics','masterCall','subCall','fundingScheme','objective','grantDoi']]

# %%
projects_['topics'].tolist()
# Out:
# ['HORIZON-HLTH-2024-DISEASE-08-20',
#  'HORIZON-CL5-2024-D2-01-02',
#  'HORIZON-CL5-2023-D2-02-02',
#  'HORIZON-HLTH-2024-DISEASE-03-14-two-stage',
#  'HORIZON-HLTH-2024-DISEASE-03-11-two-stage',
#  'HORIZON-HLTH-2024-DISEASE-03-13-two-stage',
#  'HORIZON-HLTH-2024-DISEASE-03-14-two-stage',
#  'HORIZON-HLTH-2024-DISEASE-03-14-two-stage',
#  'HORIZON-CL5-2024-D2-01-02',
#  'HORIZON-CL5-2023-D5-01-09',
#  'HORIZON-HLTH-2024-TOOL-11-02',
#  'HORIZON-HLTH-2024-TOOL-11-02',
#  'HORIZON-CL5-2024-D4-01-03',
#  'HORIZON-CL5-2024-D5-01-02',
#  'HORIZON-CL5-2024-D5-01-03',
#  'HORIZON-CL5-2024-D5-01-02',
#  'HORIZON-CL5-2023-D3-03-01',
#  'HORIZON-CL5-2024-D4-01-02',
#  'HORIZON-CL5-2024-D2-01-04',
#  'HORIZON-CL5-2024-D4-01-02',
#  'HORIZON-CL5-2024-D4-01-03',
#  'HORIZON-CL5-2024-D5-01-08',
#  'HORIZON-HLTH-2024-DISEASE-08-20',
#  'HORIZON-HLTH-2024-IND-06-08',
#  'HORIZON-CL5-2024-EUDSO-IBA-2',
#  'HORIZON-CL5-2024-D3-01-02',
#  'HORIZON-HLTH-2024-DISEASE-08-20',
#  'HORIZON-EURATOM-2024-SAPEA-IBA',
#  'HORIZON-INFRA-2024-DEV-01-02',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-ACCESS-04-01',
#  'HORIZON-WIDERA-2022-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-ACCESS-03-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2024-COST-SGA',
#  'HORIZON-WIDERA-2023-ACCESS-07-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-ACCESS-01-01-two-stage',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-ACCESS-07-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-ACCESS-01-01-two-stage',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-WIDERA-2023-ERA-01-03',
#  'HORIZON-CL6-2023-CircBio-01-6',
#  'HORIZON-CL6-2023-CLIMATE-01-5',
#  'HORIZON-CL6-2023-GOVERNANCE-01-20',
#  'HORIZON-WIDERA-2023-ACCESS-02-02',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL3-2023-SSRI-01-02',
#  'HORIZON-CL6-2023-COMMUNITIES-01-1',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-04',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-04',
#  'HORIZON-CL4-2024-RESILIENCE-01-01',
#  'HORIZON-CL4-2023-HUMAN-01-13',
#  'HORIZON-CL4-2024-RESILIENCE-01-10',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-44',
#  'HORIZON-INFRA-2023-DEV-01-02',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL4-2024-RESILIENCE-01-41',
#  'HORIZON-WIDERA-2023-ACCESS-07-01',
#  'HORIZON-WIDERA-2023-ACCESS-04-01',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-45',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL4-2024-SPACE-01-73',
#  'HORIZON-EUSPA-2022-SPACE-02-56',
#  'HORIZON-EUSPA-2023-SPACE-01-46',
#  'HORIZON-EUSPA-2022-SPACE-02-51',
#  'HORIZON-EUSPA-2022-SPACE-02-54',
#  'HORIZON-EUSPA-2023-SPACE-01-46',
#  'HORIZON-EUSPA-2023-SPACE-01-43',
#  'HORIZON-EUSPA-2022-SPACE-02-56',
#  'HORIZON-CL2-2023-DEMOCRACY-01-01',
#  'HORIZON-CL4-2023-SPACE-01-12',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-CL6-2023-CircBio-02-2-two-stage',
#  'HORIZON-CL4-2023-HUMAN-01-66',
#  'HORIZON-CL5-2024-D2-01-03',
#  'HORIZON-MISS-2023-OCEAN-01-10',
#  'HORIZON-MISS-2023-OCEAN-01-05',
#  'HORIZON-MISS-2023-CLIMA-CITIES-01-01',
#  'HORIZON-CL6-2024-CircBio-01-1',
#  'HORIZON-EIE-2023-CONNECT-02-01',
#  'HORIZON-EIE-2022-SCALEUP-02-01',
#  'HORIZON-EIE-2023-CONNECT-01-01',
#  'HORIZON-EIE-2023-CONNECT-02-02',
#  'HORIZON-EIE-2023-CONNECT-02-02',
#  'HORIZON-CL6-2024-CLIMATE-01-6',
#  'HORIZON-EUSPA-2022-SPACE-02-54',
#  'HORIZON-CL4-2023-SPACE-01-72',
#  'HORIZON-CL5-2023-D2-01-07',
#  'HORIZON-EUSPA-2023-SPACE-01-61',
#  'HORIZON-WIDERA-2023-ERA-01-08',
#  'HORIZON-CL2-2024-HERITAGE-01-01',
#  'HORIZON-CL4-2023-HUMAN-01-53',
#  'HORIZON-CL5-2024-D2-01-04',
#  'HORIZON-CL5-2024-D3-01-15',
#  'HORIZON-CL4-2024-SPACE-01-73',
#  'HORIZON-CL4-2023-HUMAN-01-21',
#  'HORIZON-MISS-2023-OCEAN-01-11',
#  'HORIZON-CL5-2024-D5-01-08',
#  'HORIZON-CL5-2024-D5-01-16',
#  'HORIZON-CL5-2022-D6-01-08',
#  'HORIZON-CL5-2024-D5-01-18',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-45',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-02',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-02',
#  'HORIZON-CL2-2023-HERITAGE-ECCCH-01-02',
#  'HORIZON-EIE-2022-SCALEUP-02-01',
#  'HORIZON-WIDERA-2023-ACCESS-04-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-CL2-2023-HERITAGE-01-05',
#  'HORIZON-WIDERA-2023-ACCESS-07-01',
#  'HORIZON-CL6-2024-FARM2FORK-01-2',
#  'HORIZON-CL6-2023-CLIMATE-01-2',
#  'HORIZON-CL2-2024-DEMOCRACY-01-11',
#  'HORIZON-EUSPA-2023-SPACE-01-46',
#  'HORIZON-WIDERA-2023-ACCESS-04-01',
#  'HORIZON-MISS-2023-SOIL-01-08',
#  'HORIZON-CL2-2024-DEMOCRACY-01-04',
#  'HORIZON-WIDERA-2023-ACCESS-02-02',
#  'HORIZON-CL4-2023-SPACE-01-22',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-51',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-46',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-10',
#  'HORIZON-CL6-2023-CircBio-01-7',
#  'HORIZON-CL6-2024-BIODIV-01-2',
#  'HORIZON-CL4-2023-HUMAN-01-03',
#  'HORIZON-EIE-2023-CONNECT-02-02',
#  'HORIZON-WIDERA-2023-ERA-01-03',
#  'HORIZON-CL2-2024-HERITAGE-01-04',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-04',
#  'HORIZON-HLTH-2023-DISEASE-03-03',
#  'HORIZON-WIDERA-2023-ACCESS-02-02',
#  'HORIZON-CL2-2024-HERITAGE-01-03',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-03',
#  'HORIZON-MISS-2023-OCEAN-01-04',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-08',
#  'HORIZON-CL4-2023-SPACE-01-62',
#  'HORIZON-EUSPA-2023-SPACE-01-43',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL4-2023-HUMAN-01-82',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-06',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-45',
#  'HORIZON-CL4-2024-SPACE-01-73',
#  'HORIZON-CL5-2023-D2-01-07',
#  'HORIZON-WIDERA-2023-ACCESS-07-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-CL6-2024-FARM2FORK-01-11',
#  'HORIZON-CL2-2023-DEMOCRACY-01-06',
#  'HORIZON-CL2-2024-DEMOCRACY-01-03',
#  'HORIZON-CL5-2023-D5-01-01',
#  'HORIZON-CL6-2023-FARM2FORK-01-3',
#  'HORIZON-CL2-2023-HERITAGE-01-07',
#  'HORIZON-WIDERA-2023-ACCESS-02-02',
#  'HORIZON-CL6-2023-CircBio-01-1',
#  'HORIZON-CL4-2023-RESILIENCE-01-06',
#  'HORIZON-EIE-2023-CONNECT-02-01',
#  'HORIZON-CL5-2023-D6-01-01',
#  'HORIZON-CL6-2023-CircBio-02-2-two-stage',
#  'HORIZON-CL4-2024-RESILIENCE-01-11',
#  'HORIZON-CL5-2024-D3-01-10',
#  'HORIZON-CL4-2023-RESILIENCE-01-23',
#  'HORIZON-CL5-2023-D3-02-16',
#  'HORIZON-CL6-2023-CircBio-01-12',
#  'HORIZON-EUSPA-2023-SPACE-01-61',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-09',
#  'HORIZON-CL6-2023-FARM2FORK-01-5',
#  'HORIZON-CL4-2023-SPACE-01-71',
#  'HORIZON-CL5-2023-D3-01-13',
#  'HORIZON-CL6-2023-ZEROPOLLUTION-01-7',
#  'HORIZON-CL2-2023-DEMOCRACY-01-07',
#  'HORIZON-CL5-2023-D1-01-06',
#  'HORIZON-CL6-2023-ZEROPOLLUTION-02-2-two-stage',
#  'HORIZON-MISS-2023-OCEAN-01-08',
#  'HORIZON-CL6-2023-CircBio-02-1-two-stage',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-03',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-02',
#  'HORIZON-CL6-2023-CLIMATE-01-7',
#  'HORIZON-HLTH-2023-CARE-04-02',
#  'HORIZON-CL4-2024-RESILIENCE-01-01',
#  'HORIZON-WIDERA-2023-ACCESS-03-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-MISS-2023-SOIL-01-02',
#  'HORIZON-CL4-2023-HUMAN-01-31',
#  'HORIZON-CL5-2024-D2-01-01',
#  'HORIZON-CL5-2023-D4-01-04',
#  'HORIZON-CL6-2023-GOVERNANCE-01-18',
#  'HORIZON-MISS-2022-SOIL-01-07',
#  'HORIZON-EUSPA-2023-SPACE-01-46',
#  'HORIZON-CL2-2023-DEMOCRACY-01-04',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-09',
#  'HORIZON-CL5-2023-D3-02-08',
#  'HORIZON-CL6-2023-GOVERNANCE-02-1',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL5-2024-D3-01-04',
#  'HORIZON-CL6-2023-CircBio-01-2',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL6-2023-ZEROPOLLUTION-01-4',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL6-2024-COMMUNITIES-01-1',
#  'HORIZON-CL6-2024-GOVERNANCE-01-8',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-46',
#  'HORIZON-WIDERA-2023-ACCESS-02-02',
#  'HORIZON-WIDERA-2023-ACCESS-02-02',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-40',
#  'HORIZON-CL6-2024-GOVERNANCE-01-11',
#  'HORIZON-CL4-2023-RESILIENCE-01-34',
#  'HORIZON-CL6-2023-CircBio-01-7',
#  'HORIZON-CL6-2023-CircBio-01-8',
#  'HORIZON-CL2-2024-HERITAGE-01-02',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-07',
#  'HORIZON-CL2-2023-HERITAGE-01-07',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-50',
#  'HORIZON-CL4-2024-DATA-01-05',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-WIDERA-2023-ACCESS-01-01-two-stage',
#  'HORIZON-CL2-2024-DEMOCRACY-01-04',
#  'HORIZON-CL6-2023-CircBio-01-12',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-01',
#  'HORIZON-CL5-2024-D1-01-07',
#  'HORIZON-CL6-2023-BIODIV-01-14',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL5-2023-D3-01-14',
#  'HORIZON-CL5-2022-D2-01-05',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-31',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-04',
#  'HORIZON-CL6-2023-BIODIV-01-16',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL6-2024-ZEROPOLLUTION-01-1',
#  'HORIZON-CL2-2024-HERITAGE-01-03',
#  'HORIZON-CL5-2023-D3-03-04',
#  'HORIZON-CL2-2023-DEMOCRACY-01-05',
#  'HORIZON-CL6-2023-CircBio-01-9',
#  'HORIZON-CL5-2023-D3-02-16',
#  'HORIZON-INFRA-2024-SESAME-IBA',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL2-2023-HERITAGE-01-05',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL5-2024-D3-01-10',
#  'HORIZON-HLTH-2024-STAYHLTH-01-05-two-stage',
#  'HORIZON-CL6-2023-BIODIV-01-12',
#  'HORIZON-CL2-2023-HERITAGE-ECCCH-01-02',
#  'HORIZON-INFRA-2024-DEV-01-02',
#  'HORIZON-WIDERA-2023-ACCESS-02-02',
#  'HORIZON-CL4-2024-RESILIENCE-01-04',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-02',
#  'HORIZON-MISS-2023-OCEAN-01-01',
#  'HORIZON-WIDERA-2023-ERA-01-01',
#  'HORIZON-HLTH-2023-TOOL-05-03',
#  'HORIZON-CL5-2023-D5-01-17',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-HLTH-2024-DISEASE-03-13-two-stage',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-10',
#  'HORIZON-CL5-2023-D3-02-02',
#  'HORIZON-CL2-2023-DEMOCRACY-01-07',
#  'HORIZON-WIDERA-2023-ACCESS-03-01',
#  'HORIZON-CL2-2024-HERITAGE-01-01',
#  'HORIZON-CL5-2024-D3-01-14',
#  'HORIZON-CL4-2023-RESILIENCE-01-23',
#  'HORIZON-CL6-2022-FARM2FORK-02-02-two-stage',
#  'HORIZON-CL4-2023-RESILIENCE-01-33',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL6-2024-BIODIV-01-9',
#  'HORIZON-CL5-2024-D3-01-10',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL6-2023-GOVERNANCE-01-16',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL6-2024-FARM2FORK-01-8',
#  'HORIZON-CL6-2023-FARM2FORK-01-14',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-08',
#  'HORIZON-CL5-2023-D3-03-08',
#  'HORIZON-HLTH-2024-TOOL-11-02',
#  'HORIZON-HLTH-2023-CARE-04-03',
#  'HORIZON-HLTH-2023-IND-06-04',
#  'HORIZON-HLTH-2023-TOOL-05-08',
#  'HORIZON-CL2-2023-HERITAGE-01-05',
#  'HORIZON-CL6-2024-COMMUNITIES-01-3',
#  'HORIZON-CL2-2024-HERITAGE-01-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-MSCA-2022-PF-01-01',
#  'HORIZON-CL4-2023-HUMAN-01-33',
#  'HORIZON-CL5-2024-D3-01-06',
#  'HORIZON-CL5-2024-D5-01-08',
#  'HORIZON-CL5-2023-D1-01-11',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL6-2023-COMMUNITIES-01-1',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-WIDERA-2024-ERA-01-07',
#  'HORIZON-HLTH-2023-DISEASE-03-03',
#  'HORIZON-WIDERA-2023-ERA-01-03',
#  'HORIZON-CL6-2023-BIODIV-01-10',
#  'HORIZON-CL5-2023-D3-02-16',
#  'HORIZON-MISS-2023-SOIL-01-05',
#  'HORIZON-CL2-2023-HERITAGE-01-02',
#  'HORIZON-CL6-2023-ZEROPOLLUTION-01-3',
#  'HORIZON-CL5-2023-D5-01-02',
#  'HORIZON-MISS-2023-CLIMA-01-01',
#  'HORIZON-CL5-2024-D3-01-10',
#  'HORIZON-CL2-2024-DEMOCRACY-01-06',
#  'HORIZON-CL4-2023-RESILIENCE-01-22',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL2-2023-DEMOCRACY-01-08',
#  'HORIZON-HLTH-2023-DISEASE-03-01',
#  'HORIZON-WIDERA-2024-ERA-01-01',
#  'HORIZON-HLTH-2023-IND-06-07',
#  'HORIZON-CL6-2023-FARM2FORK-01-12',
#  'HORIZON-CL2-2024-DEMOCRACY-01-03',
#  'HORIZON-CL2-2024-DEMOCRACY-01-01',
#  'HORIZON-HLTH-2023-TOOL-05-04',
#  'HORIZON-CL6-2024-BIODIV-01-5',
#  'HORIZON-HLTH-2024-DISEASE-03-08-two-stage',
#  'HORIZON-MISS-2023-CANCER-01-03',
#  'HORIZON-HLTH-2023-TOOL-05-05',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-HLTH-2023-DISEASE-03-07',
#  'HORIZON-HLTH-2023-TOOL-05-08',
#  'HORIZON-HLTH-2023-TOOL-05-03',
#  'HORIZON-HLTH-2022-DISEASE-07-02',
#  'HORIZON-WIDERA-2022-ACCESS-01-01-two-stage',
#  'HORIZON-CL6-2024-CircBio-01-5',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL6-2024-BIODIV-01-8',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-03',
#  'HORIZON-CL2-2024-HERITAGE-01-04',
#  'HORIZON-CL5-2023-D5-01-09',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-03',
#  'HORIZON-CL6-2024-FARM2FORK-01-9',
#  'HORIZON-WIDERA-2023-ACCESS-04-01',
#  'HORIZON-CL2-2023-DEMOCRACY-01-02',
#  'HORIZON-CL5-2023-D1-02-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL2-2024-DEMOCRACY-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-CL5-2023-D4-01-03',
#  'HORIZON-CL6-2023-BIODIV-01-9',
#  'HORIZON-CL2-2024-DEMOCRACY-01-02',
#  'HORIZON-HLTH-2022-DISEASE-07-03',
#  'HORIZON-CL5-2024-D3-01-04',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-01',
#  'HORIZON-CL6-2024-CLIMATE-01-3',
#  'HORIZON-CL3-2023-DRS-01-05',
#  'HORIZON-CL6-2024-GOVERNANCE-01-10',
#  'HORIZON-CL6-2024-CircBio-01-10',
#  'HORIZON-CL5-2023-D3-02-01',
#  'HORIZON-CL6-2023-CircBio-01-14',
#  'HORIZON-CL2-2024-DEMOCRACY-01-08',
#  'HORIZON-CL4-2024-RESILIENCE-01-04',
#  'HORIZON-CL6-2023-BIODIV-01-14',
#  'HORIZON-CL5-2023-D3-02-07',
#  'HORIZON-CL6-2023-FARM2FORK-01-5',
#  'HORIZON-MISS-2023-OCEAN-01-11',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-08',
#  'HORIZON-CL5-2023-D3-02-15',
#  'HORIZON-HLTH-2023-DISEASE-03-04',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL6-2023-CircBio-01-5',
#  'HORIZON-CL6-2023-BIODIV-01-5',
#  'HORIZON-EUSPA-2022-SPACE-02-61',
#  'HORIZON-CL6-2023-BIODIV-01-2',
#  'HORIZON-CL6-2024-ZEROPOLLUTION-01-1',
#  'HORIZON-CL5-2023-D1-01-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL4-2023-RESILIENCE-01-34',
#  'HORIZON-CL6-2023-FARM2FORK-01-6',
#  'HORIZON-MISS-2023-SOIL-01-04',
#  'HORIZON-CL2-2023-DEMOCRACY-01-07',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-INFRA-2023-DEV-01-03',
#  'HORIZON-CL2-2024-DEMOCRACY-01-09',
#  'HORIZON-MISS-2023-CANCER-01-04',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-05',
#  'HORIZON-HLTH-2024-DISEASE-08-20',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-HLTH-2023-CARE-04-02',
#  'HORIZON-CL6-2023-GOVERNANCE-01-16',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-INFRA-2023-DEV-01-07',
#  'HORIZON-CL6-2023-GOVERNANCE-01-19',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-CL4-2023-RESILIENCE-01-22',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-WIDERA-2023-ACCESS-01-01-two-stage',
#  'HORIZON-CL2-2024-HERITAGE-01-05',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-11',
#  'HORIZON-CL4-2023-SPACE-01-34',
#  'HORIZON-WIDERA-2023-ACCESS-01-01-two-stage',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL5-2023-D3-03-01',
#  'HORIZON-INFRA-2023-DEV-01-03',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-03',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-MISS-2023-SOIL-01-05',
#  'HORIZON-CL6-2023-CircBio-01-8',
#  'HORIZON-CL6-2023-FARM2FORK-01-20',
#  'HORIZON-CL6-2023-ZEROPOLLUTION-02-2-two-stage',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-11',
#  'HORIZON-CL5-2024-D5-01-17',
#  'HORIZON-CL5-2023-D5-01-08',
#  'HORIZON-MISS-2023-CIT-02-01',
#  'HORIZON-HLTH-2023-ENVHLTH-02-01',
#  'HORIZON-CL5-2022-D5-01-09',
#  'HORIZON-CL5-2023-D5-01-01',
#  'HORIZON-CL5-2023-D2-02-01',
#  'HORIZON-CL2-2023-DEMOCRACY-01-05',
#  'HORIZON-HLTH-2023-DISEASE-03-01',
#  'HORIZON-CL5-2023-D4-01-02',
#  'HORIZON-CL2-2024-DEMOCRACY-01-05',
#  'HORIZON-HLTH-2024-IND-06-09',
#  'HORIZON-HLTH-2023-DISEASE-03-18',
#  'HORIZON-INFRA-2023-DEV-01-07',
#  'HORIZON-WIDERA-2023-ACCESS-01-01-two-stage',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL4-2023-RESILIENCE-01-33',
#  'HORIZON-WIDERA-2023-ACCESS-04-01',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-05',
#  'HORIZON-CL4-2023-SPACE-01-22',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-46',
#  'HORIZON-CL5-2023-D1-01-11',
#  'HORIZON-CL2-2024-DEMOCRACY-01-12',
#  'HORIZON-CL2-2023-DEMOCRACY-01-04',
#  'HORIZON-CL4-2023-SPACE-01-71',
#  'HORIZON-CL6-2023-CircBio-01-4',
#  'HORIZON-MISS-2023-OCEAN-01-04',
#  'HORIZON-HLTH-2023-DISEASE-03-07',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL6-2024-BIODIV-01-7',
#  'HORIZON-HLTH-2023-ENVHLTH-02-01',
#  'HORIZON-CL6-2023-GOVERNANCE-01-19',
#  'HORIZON-CL2-2023-DEMOCRACY-01-06',
#  'HORIZON-CL5-2024-D5-01-07',
#  'HORIZON-CL4-2023-RESILIENCE-01-32',
#  'HORIZON-MISS-2023-OCEAN-01-05',
#  'HORIZON-CL6-2024-CircBio-01-2',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-08',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-CL2-2023-DEMOCRACY-01-07',
#  'HORIZON-WIDERA-2024-ERA-01-03',
#  'HORIZON-CL2-2023-HERITAGE-01-06',
#  'HORIZON-CL2-2024-DEMOCRACY-01-04',
#  'HORIZON-INFRA-2024-EOSC-01-03',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-CL4-2023-RESILIENCE-01-32',
#  'HORIZON-CL5-2023-D3-03-02',
#  'HORIZON-INFRA-2024-EOSC-01-05',
#  'HORIZON-CL5-2024-D3-01-10',
#  'HORIZON-INFRA-2023-DEV-01-07',
#  'HORIZON-CL4-2023-SPACE-01-12',
#  'HORIZON-CL6-2023-BIODIV-01-1',
#  'HORIZON-CL6-2023-BIODIV-01-4',
#  'HORIZON-CL6-2023-CLIMATE-01-3',
#  'HORIZON-INFRA-2023-DEV-01-02',
#  'HORIZON-MISS-2023-CANCER-01-01',
#  'HORIZON-CL4-2023-SPACE-01-11',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-50',
#  'HORIZON-MISS-2022-CLIMA-01-06',
#  'HORIZON-CL2-2024-DEMOCRACY-01-08',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-CL2-2024-HERITAGE-01-05',
#  'HORIZON-WIDERA-2024-ERA-01-04',
#  'HORIZON-WIDERA-2023-ACCESS-01-01-two-stage',
#  'HORIZON-CL4-2023-HUMAN-01-14',
#  'HORIZON-CL2-2023-HERITAGE-01-08',
#  'HORIZON-WIDERA-2024-ERA-01-08',
#  'HORIZON-CL5-2023-D1-01-08',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-53',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-11',
#  'HORIZON-INFRA-2024-TECH-01-01',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-50',
#  'HORIZON-CL2-2024-HERITAGE-01-02',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-12',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-HLTH-2023-DISEASE-03-07',
#  'HORIZON-INFRA-2023-DEV-01-05',
#  'HORIZON-CL5-2023-D5-01-09',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-57',
#  'HORIZON-CL4-2023-SPACE-01-71',
#  'HORIZON-CL4-2023-RESILIENCE-01-37',
#  'HORIZON-CL4-2024-SPACE-01-73',
#  'HORIZON-WIDERA-2023-ACCESS-01-01-two-stage',
#  'HORIZON-INFRA-2024-TECH-01-01',
#  'HORIZON-CL2-2024-DEMOCRACY-01-04',
#  'HORIZON-CL2-2023-DEMOCRACY-01-03',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-12',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-WIDERA-2023-ERA-01-09',
#  'HORIZON-CL5-2024-D1-01-02',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-06',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-HLTH-2023-ENVHLTH-02-02',
#  'HORIZON-HLTH-2023-DISEASE-03-04',
#  'HORIZON-HLTH-2023-ENVHLTH-02-02',
#  'HORIZON-WIDERA-2023-ERA-01-12',
#  'HORIZON-INFRA-2024-EOSC-01-04',
#  'HORIZON-CL2-2024-HERITAGE-01-05',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-12',
#  'HORIZON-HLTH-2024-ENVHLTH-02-06-two-stage',
#  'HORIZON-CL5-2023-D5-01-03',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL2-2024-DEMOCRACY-01-07',
#  'HORIZON-MISS-2023-CANCER-01-01',
#  'HORIZON-HLTH-2023-TOOL-05-08',
#  'HORIZON-INFRA-2024-TECH-01-01',
#  'HORIZON-HLTH-2023-DISEASE-03-17',
#  'HORIZON-WIDERA-2023-ACCESS-02-02',
#  'HORIZON-CL4-2023-RESILIENCE-01-32',
#  'HORIZON-CL6-2023-CircBio-01-13',
#  'HORIZON-WIDERA-2023-ACCESS-02-02',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-05',
#  'HORIZON-CL6-2024-GOVERNANCE-01-3',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-CL5-2023-D3-02-05',
#  'HORIZON-HLTH-2023-CARE-04-02',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-WIDERA-2023-ACCESS-03-01',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-37',
#  'HORIZON-CL5-2024-D2-01-04',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-04',
#  'HORIZON-CL5-2024-D1-01-06',
#  'HORIZON-WIDERA-2023-ACCESS-02-02',
#  'HORIZON-CL5-2023-D3-02-16',
#  'HORIZON-WIDERA-2023-ACCESS-03-01',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-42',
#  'HORIZON-EUSPA-2023-SPACE-01-46',
#  'HORIZON-CL3-2023-DRS-01-01',
#  'HORIZON-CL3-2023-CS-01-02',
#  'HORIZON-CL5-2023-D3-02-07',
#  'HORIZON-CL5-2023-D3-01-11',
#  'HORIZON-CL5-2024-D3-01-10',
#  'HORIZON-CL4-2023-SPACE-01-31',
#  'HORIZON-CL5-2023-D1-01-02',
#  'HORIZON-INFRA-2023-DEV-01-05',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-22',
#  'HORIZON-CL4-2023-RESILIENCE-01-21',
#  'HORIZON-CL5-2023-D3-02-07',
#  'HORIZON-WIDERA-2023-ACCESS-03-01',
#  'HORIZON-CL6-2023-FARM2FORK-01-7',
#  'HORIZON-CL6-2023-CLIMATE-01-8',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-54',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-02',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL4-2023-RESILIENCE-01-21',
#  'HORIZON-CL6-2023-BIODIV-01-7',
#  'HORIZON-CL6-2023-BIODIV-01-4',
#  'HORIZON-WIDERA-2023-ACCESS-04-01',
#  'HORIZON-CL2-2024-HERITAGE-01-02',
#  'HORIZON-CL5-2023-D3-02-10',
#  'HORIZON-MISS-2023-OCEAN-01-06',
#  'HORIZON-CL5-2024-D1-01-02',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL4-2023-RESILIENCE-01-34',
#  'HORIZON-MISS-2023-CIT-01-02',
#  'HORIZON-HLTH-2023-TOOL-05-08',
#  'HORIZON-CL6-2023-CLIMATE-01-3',
#  'HORIZON-CL6-2023-BIODIV-01-4',
#  'HORIZON-CL6-2024-FARM2FORK-01-2',
#  'HORIZON-CL6-2023-CircBio-01-11',
#  'HORIZON-CL5-2023-D3-01-05',
#  'HORIZON-CL5-2022-D1-01-02-two-stage',
#  'HORIZON-CL6-2024-ZEROPOLLUTION-01-3',
#  'HORIZON-CL4-2024-RESILIENCE-01-24',
#  'HORIZON-CL6-2023-BIODIV-01-5',
#  'HORIZON-CL4-2023-HUMAN-01-32',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-10',
#  'HORIZON-EUSPA-2023-SPACE-01-42',
#  'HORIZON-CL5-2023-D3-02-16',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-02',
#  'HORIZON-CL5-2023-D2-01-06',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-40',
#  'HORIZON-CL5-2023-D2-01-02',
#  'HORIZON-CL4-2023-RESILIENCE-01-05',
#  'HORIZON-WIDERA-2023-ACCESS-03-01',
#  'HORIZON-CL5-2023-D3-02-04',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-07',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL5-2023-D3-02-15',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-21',
#  'HORIZON-CL4-2023-SPACE-01-22',
#  'HORIZON-CL5-2023-D5-01-11',
#  'HORIZON-CL5-2024-D2-01-04',
#  'HORIZON-CL5-2023-D3-02-15',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-45',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-41',
#  'HORIZON-CL4-2024-RESILIENCE-01-08',
#  'HORIZON-HLTH-2023-TOOL-05-03',
#  'HORIZON-CL5-2023-D3-02-07',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-CL5-2024-D3-01-14',
#  'HORIZON-INFRA-2023-TECH-01-01',
#  'HORIZON-HLTH-2023-DISEASE-03-17',
#  'HORIZON-CL5-2023-D3-01-13',
#  'HORIZON-CL4-2023-RESILIENCE-01-05',
#  'HORIZON-CL4-2023-SPACE-01-71',
#  'HORIZON-CL3-2023-INFRA-01-02',
#  'HORIZON-WIDERA-2022-ACCESS-01-01-two-stage',
#  'HORIZON-CL4-2023-SPACE-PARTNERSHIP-IBA',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-44',
#  'HORIZON-CL5-2024-D3-01-06',
#  'HORIZON-CL4-2023-SPACE-01-12',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-05',
#  'HORIZON-CL5-2023-D2-01-05',
#  'HORIZON-CL4-2023-HUMAN-01-62',
#  'HORIZON-CL5-2023-D3-03-01',
#  'HORIZON-CL4-2023-SPACE-01-72',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-02',
#  'HORIZON-CL4-2024-RESILIENCE-01-24',
#  'HORIZON-CL5-2024-D3-01-03',
#  'HORIZON-CL3-2023-CS-01-02',
#  'HORIZON-CL6-2023-ZEROPOLLUTION-01-7',
#  'HORIZON-CL4-2023-SPACE-01-21',
#  'HORIZON-CL5-2022-D3-03-05',
#  'HORIZON-CL5-2023-D3-01-04',
#  'HORIZON-CL5-2023-D3-01-14',
#  'HORIZON-CL5-2023-D3-02-14',
#  'HORIZON-CL3-2023-BM-01-02',
#  'HORIZON-INFRA-2023-DEV-01-01',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-02',
#  'HORIZON-CL5-2024-D3-01-01',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-04',
#  'HORIZON-CL5-2023-D2-01-04',
#  'HORIZON-CL5-2023-D3-02-08',
#  'HORIZON-CL2-2024-DEMOCRACY-01-11',
#  'HORIZON-CL5-2023-D2-01-02',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL5-2023-D2-02-03',
#  'HORIZON-CL6-2024-CircBio-01-6',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-53',
#  'HORIZON-MISS-2023-CLIMA-01-01',
#  'HORIZON-CL4-2023-HUMAN-01-21',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-02',
#  'HORIZON-MISS-2023-OCEAN-01-05',
#  'HORIZON-CL5-2024-D3-01-02',
#  'HORIZON-CL5-2023-D3-02-06',
#  'HORIZON-INFRA-2023-EOSC-01-06',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-22',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-57',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-41',
#  'HORIZON-CL2-2024-DEMOCRACY-01-09',
#  'HORIZON-CL4-2024-SPACE-01-73',
#  'HORIZON-CL5-2023-D3-01-13',
#  'HORIZON-CL5-2023-D2-02-01',
#  'HORIZON-HLTH-2023-DISEASE-03-04',
#  'HORIZON-HLTH-2023-IND-06-05',
#  'HORIZON-CL2-2023-HERITAGE-01-02',
#  'HORIZON-INFRA-2023-DEV-01-03',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-02',
#  'HORIZON-CL5-2023-D3-02-02',
#  'HORIZON-CL4-2023-RESILIENCE-01-42',
#  'HORIZON-INFRA-2024-DEV-01-01',
#  'HORIZON-CL6-2023-CircBio-02-1-two-stage',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-04',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-11',
#  'HORIZON-CL5-2023-D2-01-03',
#  'HORIZON-CL5-2024-D3-01-10',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-02',
#  'HORIZON-CL4-2023-RESILIENCE-01-09',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-09',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-10',
#  'HORIZON-WIDERA-2023-TALENTS-01-01',
#  'HORIZON-MISS-2022-CLIMA-01-05',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-WIDERA-2023-ACCESS-04-01',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-43',
#  'HORIZON-CL5-2024-D3-01-17',
#  'HORIZON-CL5-2023-D2-02-01',
#  'HORIZON-CL2-2024-DEMOCRACY-01-02',
#  'HORIZON-HLTH-2023-CARE-04-02',
#  'HORIZON-EURATOM-2023-NRT-01-01',
#  'HORIZON-WIDERA-2023-ACCESS-04-01',
#  'HORIZON-WIDERA-2024-ERA-01-01',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-41',
#  'HORIZON-CL6-2024-BIODIV-01-1',
#  'HORIZON-INFRA-2023-SERV-01-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL6-2023-ZEROPOLLUTION-01-3',
#  'HORIZON-CL6-2023-BIODIV-01-17',
#  'HORIZON-INFRA-2023-EOSC-01-01',
#  'HORIZON-INFRA-2024-DEV-01-01',
#  'HORIZON-CL2-2023-HERITAGE-01-06',
#  'HORIZON-MISS-2023-OCEAN-01-02',
#  'HORIZON-CL2-2024-DEMOCRACY-01-06',
#  'HORIZON-CL2-2024-HERITAGE-01-02',
#  'HORIZON-MISS-2023-OCEAN-01-02',
#  'HORIZON-CL2-2024-HERITAGE-01-04',
#  'HORIZON-CL2-2023-DEMOCRACY-01-04',
#  'HORIZON-CL6-2023-BIODIV-01-1',
#  'HORIZON-CL6-2023-ZEROPOLLUTION-01-6',
#  'HORIZON-INFRA-2023-DEV-01-04',
#  'HORIZON-HLTH-2023-ENVHLTH-02-01',
#  'HORIZON-CL6-2023-GOVERNANCE-01-12',
#  'HORIZON-HLTH-2023-ENVHLTH-02-03',
#  'HORIZON-CL5-2023-D3-03-03',
#  'HORIZON-CL5-2023-D5-01-04',
#  'HORIZON-CL5-2023-D5-01-01',
#  'HORIZON-CL5-2023-D5-01-02',
#  'HORIZON-CL5-2023-D6-01-13',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL6-2023-GOVERNANCE-01-8',
#  'HORIZON-EIE-2023-CONNECT-02-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-HLTH-2023-CARE-04-02',
#  'HORIZON-CL4-2023-HUMAN-01-54',
#  'HORIZON-CL4-2023-RESILIENCE-01-42',
#  'HORIZON-WIDERA-2023-ACCESS-01-01-two-stage',
#  'HORIZON-CL4-2024-RESILIENCE-01-41',
#  'HORIZON-CL5-2023-D2-01-05',
#  'HORIZON-CL4-2023-DATA-01-02',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-04',
#  'HORIZON-CL5-2024-D3-01-12',
#  'HORIZON-CL5-2022-D4-02-02',
#  'HORIZON-CL5-2023-D6-01-03',
#  'HORIZON-CL5-2023-D3-02-13',
#  'HORIZON-CL5-2024-D3-01-08',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-CL4-2023-DATA-01-06',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-45',
#  'HORIZON-CL4-2023-RESILIENCE-01-09',
#  'HORIZON-CL5-2023-D5-01-11',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-23',
#  'HORIZON-CL6-2024-CircBio-01-3',
#  'HORIZON-CL4-2024-RESILIENCE-01-11',
#  'HORIZON-CL5-2023-D4-02-02',
#  'HORIZON-CL4-2023-RESILIENCE-01-05',
#  'HORIZON-WIDERA-2023-ACCESS-04-01',
#  'HORIZON-CL6-2023-CircBio-01-1',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-05',
#  'HORIZON-CL6-2023-GOVERNANCE-01-2',
#  'HORIZON-CL5-2023-D2-01-04',
#  'HORIZON-CL6-2023-FARM2FORK-01-19',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-02',
#  'HORIZON-CL6-2023-FARM2FORK-01-17',
#  'HORIZON-CL4-2023-SPACE-01-32',
#  'HORIZON-CL6-2023-FARM2FORK-01-11',
#  'HORIZON-CL5-2023-D6-01-03',
#  'HORIZON-INFRA-2023-DEV-01-03',
#  'HORIZON-MISS-2023-CANCER-01-03',
#  'HORIZON-HLTH-2023-DISEASE-03-01',
#  'HORIZON-HLTH-2023-DISEASE-03-01',
#  'HORIZON-HLTH-2022-DISEASE-06-04-two-stage',
#  'HORIZON-HLTH-2023-IND-06-04',
#  'HORIZON-HLTH-2023-IND-06-07',
#  'HORIZON-CL6-2023-CircBio-01-11',
#  'HORIZON-CL5-2023-D5-01-08',
#  'HORIZON-CL5-2023-D3-02-04',
#  'HORIZON-HLTH-2023-TOOL-05-05',
#  'HORIZON-WIDERA-2023-ACCESS-02-02',
#  'HORIZON-EIE-2023-CONNECT-02-02',
#  'HORIZON-CL5-2024-D3-01-12',
#  'HORIZON-HLTH-2024-DISEASE-08-20',
#  'HORIZON-CL6-2022-GOVERNANCE-01-03',
#  'HORIZON-CL6-2024-CLIMATE-01-3',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-09',
#  'HORIZON-HLTH-2023-CARE-04-01',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-11',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-03',
#  'HORIZON-HLTH-2023-ENVHLTH-02-03',
#  'HORIZON-INFRA-2023-EOSC-01-06',
#  'HORIZON-CL6-2024-CLIMATE-01-2',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-04',
#  'HORIZON-CL2-2024-DEMOCRACY-01-09',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-02',
#  'HORIZON-HLTH-2023-DISEASE-03-07',
#  'HORIZON-CL4-2023-DATA-01-04',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-31',
#  'HORIZON-CL4-2023-RESILIENCE-01-33',
#  'HORIZON-CL4-2023-SPACE-01-31',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-36',
#  'HORIZON-MISS-2023-CIT-SGA-01',
#  'HORIZON-CL5-2023-D3-02-05',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-45',
#  'HORIZON-CL5-2023-D3-03-05',
#  'HORIZON-CL4-2024-RESILIENCE-01-24',
#  'HORIZON-CL5-2023-D6-01-06',
#  'HORIZON-CL5-2023-D3-01-03',
#  'HORIZON-CL5-2023-D3-02-12',
#  'HORIZON-EUSPA-2023-SPACE-01-42',
#  'HORIZON-EUSPA-2022-SPACE-02-61',
#  'HORIZON-CL5-2023-D3-02-14',
#  'HORIZON-CL5-2024-D3-01-07',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-10',
#  'HORIZON-CL2-2024-DEMOCRACY-01-05',
#  'HORIZON-CL2-2024-HERITAGE-01-05',
#  'HORIZON-CL6-2023-BIODIV-01-17',
#  'HORIZON-WIDERA-2023-ACCESS-02-02',
#  'HORIZON-CL2-2023-HERITAGE-01-03',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-53',
#  'HORIZON-HLTH-2023-DISEASE-03-04',
#  'HORIZON-CL4-2024-DATA-01-01',
#  'HORIZON-CL5-2023-D2-01-07',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-HLTH-2024-STAYHLTH-01-05-two-stage',
#  'HORIZON-CL2-2023-DEMOCRACY-01-03',
#  'HORIZON-HLTH-2023-ENVHLTH-02-03',
#  'HORIZON-CL2-2024-HERITAGE-01-01',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-07',
#  'HORIZON-WIDERA-2023-ACCESS-02-02',
#  'HORIZON-CL2-2023-HERITAGE-01-02',
#  'HORIZON-HLTH-2023-IND-06-01',
#  'HORIZON-INFRA-2023-SERV-01-02',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-11',
#  'HORIZON-CL2-2024-HERITAGE-01-04',
#  'HORIZON-CL2-2023-HERITAGE-01-04',
#  'HORIZON-HLTH-2023-DISEASE-03-18',
#  'HORIZON-CL5-2023-D1-01-10',
#  'HORIZON-HLTH-2024-ENVHLTH-02-06-two-stage',
#  'HORIZON-CL6-2022-FARM2FORK-01-09',
#  'HORIZON-HLTH-2023-DISEASE-03-04',
#  'HORIZON-HLTH-2023-ENVHLTH-02-03',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-05',
#  'HORIZON-CL6-2023-ZEROPOLLUTION-01-5',
#  'HORIZON-MISS-2023-CANCER-01-01',
#  'HORIZON-INFRA-2023-DEV-01-05',
#  'HORIZON-CL2-2023-DEMOCRACY-01-04',
#  'HORIZON-CL5-2024-D1-01-03',
#  'HORIZON-CL6-2023-ZEROPOLLUTION-01-4',
#  'HORIZON-CL6-2024-FARM2FORK-01-10',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-02',
#  'HORIZON-CL5-2023-D3-02-13',
#  'HORIZON-CL4-2023-HUMAN-01-11',
#  'HORIZON-CL6-2022-COMMUNITIES-02-01-two-stage',
#  'HORIZON-WIDERA-2023-ACCESS-07-01',
#  'HORIZON-CL5-2023-D3-03-05',
#  'HORIZON-CL2-2024-TRANSFORMATIONS-01-06',
#  'HORIZON-HLTH-2023-STAYHLTH-01-01',
#  'HORIZON-CL2-2023-HERITAGE-01-07',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-50',
#  'HORIZON-MISS-2023-OCEAN-01-02',
#  'HORIZON-CL5-2023-D1-01-02',
#  'HORIZON-CL6-2024-BIODIV-01-8',
#  'HORIZON-MISS-2023-CLIMA-01-01',
#  'HORIZON-CL5-2024-D3-01-11',
#  'HORIZON-CL5-2023-D3-01-05',
#  'HORIZON-EUSPA-2023-SPACE-01-46',
#  'HORIZON-CL5-2023-D5-01-08',
#  'HORIZON-CL6-2023-CircBio-01-5',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-46',
#  'HORIZON-CL6-2023-ZEROPOLLUTION-02-1-two-stage',
#  'HORIZON-CL4-2024-QUANTUM-01-SGA',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-11',
#  'HORIZON-HLTH-2024-TOOL-05-06-two-stage',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-33',
#  'HORIZON-CL5-2023-D3-01-05',
#  'HORIZON-CL6-2024-CircBio-01-10',
#  'HORIZON-HLTH-2023-TOOL-05-03',
#  'HORIZON-CL5-2023-D5-01-07',
#  'HORIZON-MISS-2023-SOIL-01-06',
#  'HORIZON-INFRA-2023-SERV-01-01',
#  'HORIZON-INFRA-2024-DEV-01-03',
#  'HORIZON-WIDERA-2023-ACCESS-01-01-two-stage',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-35',
#  'HORIZON-CL5-2023-D3-03-06',
#  'HORIZON-CL5-2023-D3-02-11',
#  'HORIZON-CL5-2023-D5-01-15',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-41',
#  'HORIZON-CL6-2024-CLIMATE-01-5',
#  'HORIZON-CL6-2024-COMMUNITIES-01-2',
#  'HORIZON-CL5-2023-D3-02-11',
#  'HORIZON-HLTH-2024-TOOL-05-06-two-stage',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-56',
#  'HORIZON-CL5-2023-D3-02-11',
#  'HORIZON-CL4-2023-HUMAN-01-63',
#  'HORIZON-CL5-2023-D5-01-08',
#  'HORIZON-EUSPA-2023-SPACE-01-42',
#  'HORIZON-WIDERA-2023-ACCESS-02-02',
#  'HORIZON-CL5-2023-D5-01-09',
#  'HORIZON-INFRA-2024-TECH-01-03',
#  'HORIZON-CL4-2023-HUMAN-01-22',
#  'HORIZON-HLTH-2023-TOOL-05-04',
#  'HORIZON-CL2-2024-DEMOCRACY-01-02',
#  'HORIZON-CL5-2023-D3-02-09',
#  'HORIZON-CL5-2024-D3-01-16',
#  'HORIZON-CL5-2024-D3-01-07',
#  'HORIZON-HLTH-2023-ENVHLTH-02-01',
#  'HORIZON-CL6-2023-CircBio-01-2',
#  'HORIZON-CL6-2023-ZEROPOLLUTION-01-1',
#  'HORIZON-HLTH-2023-ENVHLTH-02-02',
#  'HORIZON-CL6-2023-CircBio-01-4',
#  'HORIZON-CL6-2024-BIODIV-01-6',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL2-2023-DEMOCRACY-01-01',
#  'HORIZON-CL2-2023-DEMOCRACY-01-08',
#  'HORIZON-CL6-2023-BIODIV-01-2',
#  'HORIZON-CL6-2023-GOVERNANCE-01-4',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-11',
#  'HORIZON-CL6-2024-BIODIV-01-3',
#  'HORIZON-CL2-2024-DEMOCRACY-01-01',
#  'HORIZON-CL6-2023-BIODIV-01-11',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL5-2023-D1-01-03',
#  'HORIZON-INFRA-2023-SERV-01-01',
#  'HORIZON-MSCA-2023-CITIZENS-01-01',
#  'HORIZON-INFRA-2023-TECH-01-01',
#  'HORIZON-INFRA-2023-DEV-01-03',
#  'HORIZON-CL6-2023-BIODIV-01-1',
#  'HORIZON-CL6-2023-BIODIV-01-7',
#  'HORIZON-CL5-2023-D3-02-12',
#  'HORIZON-CL5-2024-D5-01-07',
#  'HORIZON-CL5-2023-D3-01-12',
#  'HORIZON-CL5-2024-D1-01-02',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-07',
#  'HORIZON-CL2-2023-TRANSFORMATIONS-01-09',
#  'HORIZON-CL5-2023-D3-01-17',
#  'HORIZON-INFRA-2024-TECH-01-01',
#  'HORIZON-CL6-2023-BIODIV-01-15',
#  'HORIZON-CL2-2023-DEMOCRACY-01-08',
#  'HORIZON-CL6-2024-CLIMATE-01-5',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-HLTH-2024-TOOL-11-02',
#  'HORIZON-CL5-2023-D1-01-01',
#  'HORIZON-INFRA-2024-TECH-01-03',
#  'HORIZON-INFRA-2024-TECH-01-03',
#  'HORIZON-CL5-2023-D3-02-05',
#  'HORIZON-CL5-2023-D3-02-05',
#  'HORIZON-CL5-2024-D3-01-15',
#  'HORIZON-CL5-2022-D1-02-05',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-42',
#  'HORIZON-CL4-2024-DIGITAL-EMERGING-01-04',
#  'HORIZON-CL5-2023-D4-01-02',
#  'HORIZON-CL5-2023-D3-02-15',
#  'HORIZON-CL4-2023-TWIN-TRANSITION-01-11',
#  'HORIZON-CL6-2023-CircBio-02-3-two-stage',
#  'HORIZON-CL5-2023-D5-01-12',
#  'HORIZON-HLTH-2023-TOOL-05-05',
#  'HORIZON-CL4-2023-DATA-01-07',
#  'HORIZON-CL5-2023-D3-03-07',
#  'HORIZON-CL5-2023-D3-03-07',
#  'HORIZON-CL4-2023-RESILIENCE-01-34',
#  'HORIZON-WIDERA-2023-ACCESS-02-01',
#  'HORIZON-CL4-2023-RESILIENCE-01-03',
#  'HORIZON-CL5-2022-D2-01-07',
#  'HORIZON-CL5-2023-D3-01-06',
#  'HORIZON-CL4-2023-DIGITAL-EMERGING-01-51',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-34',
#  'HORIZON-CL4-2023-DATA-01-04',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-05',
#  'HORIZON-CL4-2024-TWIN-TRANSITION-01-35',
#  'HORIZON-CL5-2023-D6-01-11',
#  'HORIZON-CL5-2024-D2-01-04',
#  'HORIZON-CL5-2024-D3-01-06',
#  'HORIZON-CL5-2022-D3-03-09',
#  ...]

# %%
# Define function to assign clusters
def assign_cluster(topic):
    if "CL2" in topic:
        return "Cluster 2"
    elif "CL3" in topic:
        return "Cluster 3"
    elif "CL4" in topic:
        return "Cluster 4"
    elif "CL5" in topic:
        return "Cluster 5"
    elif "CL6" in topic:
        return "Cluster 6"
    elif "HLTH" in topic:
        return "Cluster Health"
    elif "MISS" in topic:
        return "Cluster MISS"
    else:
        return "Other"

# Apply function to create a new column
projects_["cluster"] = projects_["topics"].apply(assign_cluster)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5400\1596246470.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   projects_["cluster"] = projects_["topics"].apply(assign_cluster)

# %%
projects_
# Out:
#               id         acronym  \
# 3      101191725         InFlaMe
# 4      101191867         EPISODE
# 5      101147312          SAGELI
# 23     101157146     EUmetriosis
# 38     101155852        PIPELINE
# ...          ...             ...
# 14059  101165966       InnoMatch
# 14444  101167739  EIC ACCESSplus
# 14571  101160467        InnoNext
# 14875  101194408           ACORN
# 14969  101131516       FlexRICAN
#
#                                                    title  startDate  \
# 3      Counter-acting the pandemic potential of flavi... 2025-01-01
# 4      European Produced sustaInable SODium-ion battE... 2024-12-01
# 5      ADVANCED SAFER MATERIALS AND HIGH PERFORMING C... 2025-01-01
# 23     EUmetriosis: Transforming endometriosis care i... 2025-01-01
# 38     Pregnancy and Infant PrEparedness pLatform IN ... 2025-01-01
# ...                                                  ...        ...
# 14059                    Matching innovators with buyers 2024-09-01
# 14444  Advancing Cross-border Coaching and Economic s... 2024-08-01
# 14571  The Next Generation Innovation Talents' initia... 2024-08-01
# 14875  Advancing Circular Economy with Bio-Based Solu... 2024-11-01
# 14969    Flexibility in RIs for global CArbon Neutrality 2024-03-01
#
#          endDate   totalCost   legalBasis  \
# 3     2028-12-31   7995922,4  HORIZON.2.1
# 4     2028-05-31           0  HORIZON.2.5
# 5     2027-12-31  4975670,75  HORIZON.2.5
# 23    2029-12-31           0  HORIZON.2.1
# 38    2028-12-31           0  HORIZON.2.1
# ...          ...         ...          ...
# 14059 2027-08-31     2999875  HORIZON.3.1
# 14444 2026-07-31     4499625  HORIZON.3.1
# 14571 2026-07-31     3986000  HORIZON.3.1
# 14875 2026-08-31           0  HORIZON.3.1
# 14969 2027-02-28           0  HORIZON.1.3
#
#                                           topics  \
# 3                HORIZON-HLTH-2024-DISEASE-08-20
# 4                      HORIZON-CL5-2024-D2-01-02
# 5                      HORIZON-CL5-2023-D2-02-02
# 23     HORIZON-HLTH-2024-DISEASE-03-14-two-stage
# 38     HORIZON-HLTH-2024-DISEASE-03-11-two-stage
# ...                                          ...
# 14059            HORIZON-EIC-2023-INNOVPRO-01-01
# 14444            HORIZON-EIC-2023-PARTNERS-01-01
# 14571             HORIZON-EIC-2023-TALENTS-01-01
# 14875            HORIZON-EIC-2024-BOOSTER-IBA-01
# 14969              HORIZON-INFRA-2023-TECH-01-01
#
#                                    masterCall  \
# 3                HORIZON-HLTH-2024-DISEASE-08
# 4                      HORIZON-CL5-2024-D2-01
# 5                      HORIZON-CL5-2023-D2-02
# 23     HORIZON-HLTH-2024-DISEASE-03-two-stage
# 38     HORIZON-HLTH-2024-DISEASE-03-two-stage
# ...                                       ...
# 14059            HORIZON-EIC-2023-INNOVPRO-01
# 14444            HORIZON-EIC-2023-PARTNERS-01
# 14571             HORIZON-EIC-2023-TALENTS-01
# 14875         HORIZON-EIC-2024-BOOSTER-IBA-01
# 14969              HORIZON-INFRA-2023-TECH-01
#
#                                       subCall fundingScheme  \
# 3                HORIZON-HLTH-2024-DISEASE-08   HORIZON-RIA
# 4                      HORIZON-CL5-2024-D2-01    HORIZON-IA
# 5                      HORIZON-CL5-2023-D2-02   HORIZON-RIA
# 23     HORIZON-HLTH-2024-DISEASE-03-two-stage   HORIZON-RIA
# 38     HORIZON-HLTH-2024-DISEASE-03-two-stage   HORIZON-RIA
# ...                                       ...           ...
# 14059            HORIZON-EIC-2023-INNOVPRO-01   HORIZON-CSA
# 14444            HORIZON-EIC-2023-PARTNERS-01   HORIZON-CSA
# 14571             HORIZON-EIC-2023-TALENTS-01   HORIZON-CSA
# 14875         HORIZON-EIC-2024-BOOSTER-IBA-01   HORIZON-CSA
# 14969              HORIZON-INFRA-2023-TECH-01   HORIZON-RIA
#
#                                                objective           grantDoi  \
# 3      To strengthen EU's ability to fight DENV and W...  10.3030/101191725
# 4      The main mission for EPISODE is to develop a n...  10.3030/101191867
# 5      SAGELi aims to develop safer materials and cel...  10.3030/101147312
# 23     Despite its high prevalence (10% of women and ...  10.3030/101157146
# 38     Recent epidemics have highlighted how infectio...  10.3030/101155852
# ...                                                  ...                ...
# 14059  "Overcoming the challenge of finding initial c...  10.3030/101165966
# 14444  EIC-ACCESS+ mission is to enable EIC Awardees ...  10.3030/101167739
# 14571  In today's fast-paced global landscape, innova...  10.3030/101160467
# 14875  ACORN researches and develops business models ...  10.3030/101194408
# 14969  The FlexRICAN project brings together three la...  10.3030/101131516
#
#               cluster
# 3      Cluster Health
# 4           Cluster 5
# 5           Cluster 5
# 23     Cluster Health
# 38     Cluster Health
# ...               ...
# 14059           Other
# 14444           Other
# 14571           Other
# 14875           Other
# 14969           Other
#
# [1022 rows x 14 columns]

# %%
projects_.to_csv('projects.csv',index=False,sep='|')

# %%
orgs_ = orgsinprojects23nogreek[orgsinprojects23nogreek['projectID'].isin(projects_['id'].tolist())]

# %%
orgs_
# Out:
#        projectID projectAcronym  organisationID       vatNumber  \
# 20     101191725        InFlaMe       998189947             NaN
# 21     101191725        InFlaMe       999989976     ATU57469858
# 22     101191725        InFlaMe       999582285   IT00580590180
# 23     101191725        InFlaMe       999880657      CZ00216224
# 24     101191725        InFlaMe       999895789   IT01279680480
# ...          ...            ...             ...             ...
# 97391  101131516      FlexRICAN       983194329  SE556016864201
# 97392  101131516      FlexRICAN       910554618    BE0628655020
# 97393  101131516      FlexRICAN       919998053  SE768200001801
# 97394  101131516      FlexRICAN       999997930   FR40180089013
# 97395  101131516      FlexRICAN       999470541     DE140213784
#
#                                                     name     shortName    SME  \
# 20     ISTITUTO ZOOPROFILATTICO SPERIMENTALE DELLA LO...           NaN  False
# 21                        MEDIZINISCHE UNIVERSITAET WIEN           NaN  False
# 22               FONDAZIONE IRCCS POLICLINICO SAN MATTEO     IRCCS OSM  False
# 23                                 Masarykova univerzita            MU  False
# 24                     UNIVERSITA DEGLI STUDI DI FIRENZE         UNIFI  False
# ...                                                  ...           ...    ...
# 97391                         ALFA LAVAL TECHNOLOGIES AB           NaN  False
# 97392                 EUROPEAN MAGNETIC FIELD LABORATORY  EMFL - AISBL  False
# 97393                    EUROPEAN SPALLATION SOURCE ERIC           NaN  False
# 97394  CENTRE NATIONAL DE LA RECHERCHE SCIENTIFIQUE CNRS          CNRS  False
# 97395            HELMHOLTZ-ZENTRUM DRESDEN-ROSSENDORF EV          HZDR  False
#
#       activityType                    street postCode  ...  \
# 20             REC     VIA ANTONIO BIANCHI 9    25124  ...
# 21             HES            SPITALGASSE 23     1090  ...
# 22             REC            VIALE GOLGI 19    27100  ...
# 23             HES      Zerotinovo namesti 9   601 77  ...
# 24             HES       Piazza San Marco  4    50121  ...
# ...            ...                       ...      ...  ...
# 97391          PRC           RUDEBOKSVAGEN 1   221 00  ...
# 97392          OTH           RUE DU TRONE 98     1050  ...
# 97393          PUB        ODARSLOVSVAGEN 113   224 84  ...
# 97394          REC         RUE MICHEL ANGE 3    75794  ...
# 97395          REC  BAUTZNER LANDSTRASSE 400    01328  ...
#
#                                              contactForm    contentUpdateDate  \
# 20     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:45
# 21     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:45
# 22     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:45
# 23     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:45
# 24     https://ec.europa.eu/info/funding-tenders/oppo...  2024-12-12 11:00:45
# ...                                                  ...                  ...
# 97391  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 18:33:46
# 97392  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 18:33:46
# 97393  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 18:33:46
# 97394  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 18:33:46
# 97395  https://ec.europa.eu/info/funding-tenders/oppo...  2024-09-06 18:33:46
#
#            rcn order         role ecContribution netEcContribution  totalCost  \
# 20     2106939   7.0  participant      596937.50         596937.50   596937,5
# 21     1905549   4.0  participant      675940.00         675940.00     675940
# 22     1922908   1.0  coordinator      894484.25         894484.25  894484,25
# 23     1910106  10.0  participant      770790.00         770790.00     770790
# 24     1905657   5.0  participant      717006.90         717006.90   717006,9
# ...        ...   ...          ...            ...               ...        ...
# 97391  3099835   7.0  participant      106250.00         106250.00          0
# 97392  1965488   5.0  participant       37500.00          37500.00          0
# 97393  2720567   1.0  coordinator     1935725.00        1935725.00          0
# 97394  1905572   3.0  participant     1118375.00        1086382.00          0
# 97395  1909706   4.0  participant       78500.00          78500.00          0
#
#        endOfParticipation active
# 20                  False    NaN
# 21                  False    NaN
# 22                  False    NaN
# 23                  False    NaN
# 24                  False    NaN
# ...                   ...    ...
# 97391               False    NaN
# 97392               False    NaN
# 97393               False    NaN
# 97394               False    NaN
# 97395               False    NaN
#
# [11734 rows x 25 columns]

# %%
orgs_ = orgs_[['projectID','name','shortName','SME','activityType','city','country','organizationURL','contactForm','order','role','ecContribution']]

# %%
print (orgs_['country'].unique())
# Out:
# ['IT' 'AT' 'CZ' 'ES' 'FR' 'DE' 'NL' 'UK' 'BE' 'EE' 'PL' 'HR' 'IE' 'FI'
#  'NO' 'LU' 'DK' 'CH' 'SE' 'PT' 'RO' 'LB' 'TR' 'NZ' 'BG' 'GT' 'US' 'IN'
#  'GH' 'ZA' 'ZM' 'KE' 'LV' 'SI' 'CV' 'CA' 'LT' 'SK' 'UA' 'RS' 'CY' 'AM'
#  'IL' 'HU' 'CO' 'TZ' 'UG' 'CL' 'MV' 'MT' 'MK' 'PE' 'MA' 'PH' 'GE' 'ET'
#  'TN' 'RW' 'SN' 'TG' 'FO' 'BR' 'CM' 'AU' 'IS' nan 'BA' 'AR' 'JO' 'AL' 'CD'
#  'MW' 'BF' 'ME' 'NG' 'GL' 'TW' 'MG' 'CN' 'MD' 'TH' 'JP' 'BJ' 'CI' 'KR'
#  'KH' 'MX' 'XK' 'AW' 'GN' 'BD' 'CR' 'EG' 'SR' 'DJ' 'TD' 'DZ' 'ML' 'MC'
#  'PA']

# %%
orgs_.to_csv('orgs.csv',index=False,sep='|')

# %%
# Out:
# array(["ISTITUTO ZOOPROFILATTICO SPERIMENTALE DELLA LOMBARDIA E DELL'EMILIA ROMAGNA BRUNO UBERTINI",
#        'MEDIZINISCHE UNIVERSITAET WIEN',
#        'FONDAZIONE IRCCS POLICLINICO SAN MATTEO', ...,
#        'ELI-HU KUTATASI ES FEJLESZTESI NONPROFIT KOZHASZNU KORLATOLT FELELOSSEGU TARSASAG',
#        'ALFA LAVAL TECHNOLOGIES AB', 'EUROPEAN MAGNETIC FIELD LABORATORY'],
#       shape=(6242,), dtype=object)
